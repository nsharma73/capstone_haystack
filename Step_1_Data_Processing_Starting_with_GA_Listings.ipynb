# %% [markdown]
# <a href="https://colab.research.google.com/github/nsharma73/capstone_haystack/blob/main/Step_1_Data_Processing_Starting_with_GA_Listings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Step 1: Using Haystack Data (GA Listings) Clean Data and Augment with Tax information as well HPI data from IRS and FHFA respectively
# **Project**

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline
import matplotlib
from matplotlib import pyplot as plt
import os
from scipy import stats
import math

# %% [markdown]
# Use this to manually upload files

# %%
#from google.colab import files
#uploaded = files.upload()

# %%
# Code to read csv file into Colaboratory:
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
import sys
sys.path.append('local_modules')
# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
# choose a local (colab) directory to store the data.
local_download_path = os.path.expanduser('~/Downloads/Haystacks_Data')
try:
  os.makedirs(local_download_path)
except: pass

# 2. Auto-iterate using the query syntax
#    https://developers.google.com/drive/v2/web/search-parameters
file_list = drive.ListFile(
    {'q': "'19wbPrG4fNpmfRxypxJkzOGSZ2P0k0xre' in parents"}).GetList()

for f in file_list:
  # 3. Create & download by id.
  print('title: %s, id: %s' % (f['title'], f['id']))
  fname = os.path.join(local_download_path, f['title'])
  print('downloading to {}'.format(fname))
  f_ = drive.CreateFile({'id': f['id']})
  f_.GetContentFile(fname)

with open(fname, 'r') as f:
  print(f.read())
# Out:
# title: ga_tax_data.csv, id: 1NTUWjQ-Z7hpGHImePVdeIusW7sIrkTv_
# downloading to /root/Downloads/Haystacks_Data/ga_tax_data.csv
# title: zip5_hpi.csv, id: 1Xhrp9qlbHjilhDVIW6XVZ16bAeoxOJWq
# downloading to /root/Downloads/Haystacks_Data/zip5_hpi.csv
# title: GA_LISTINGS_SALES_V2.csv, id: 15Xt6QU-IJgcGnfVjW0uZUGEkhdHlTkFs
# downloading to /root/Downloads/Haystacks_Data/GA_LISTINGS_SALES_V2.csv
# title: zip_hpi.csv, id: 1F0P-bbpO8ntf72DYuY1LKXX5b1YlFRSp
# downloading to /root/Downloads/Haystacks_Data/zip_hpi.csv
# title: GA_LISTINGS_SALES_V2.1_excel.xlsm, id: 1BEwtEd3D-_9HNZX9mTfGNHNp2WR7MkW2
# downloading to /root/Downloads/Haystacks_Data/GA_LISTINGS_SALES_V2.1_excel.xlsm
# title: all_zips_restaurant.json, id: 1_lll8wIPsU2EnP_1hPz5hI5dFQ5VN46y
# downloading to /root/Downloads/Haystacks_Data/all_zips_restaurant.json
# title: all_zips_grocery_store.json, id: 1UrgOHYGhJxkiI9lOM3dDOj1nxz2TSDuk
# downloading to /root/Downloads/Haystacks_Data/all_zips_grocery_store.json
# title: middle_schools.csv, id: 1skl5tUyqE5x9i0EWSeSdzbOUr-W-NwBo
# downloading to /root/Downloads/Haystacks_Data/middle_schools.csv
# title: elementary_schools.csv, id: 1eBd67Jm7ysvaoNIAaCA7XByRaBvo42VF
# downloading to /root/Downloads/Haystacks_Data/elementary_schools.csv
# title: high_schools.csv, id: 1_TranYW7PKVCjFW71h1EBahZ-vVFaT9Q
# downloading to /root/Downloads/Haystacks_Data/high_schools.csv
# title: crime_rating_zipcode.csv, id: 1OM8VhoJcrC2mY91eTv1BOaqKlTgc6DRY
# downloading to /root/Downloads/Haystacks_Data/crime_rating_zipcode.csv
# title: all_zips_restaurant.json.gz, id: 1RjGfAyZ0-OvX7OMbHmCEd03FkipVpFij
# downloading to /root/Downloads/Haystacks_Data/all_zips_restaurant.json.gz
# title: all_zips_grocery_store.json.gz, id: 1bOP13mv1BRzmqX5eMUUtNVkMIcx_6A1R
# downloading to /root/Downloads/Haystacks_Data/all_zips_grocery_store.json.gz
# title: GA_LISTINGS_SALES.csv, id: 19BrRGNQkAmCvN0voquxCrbZFolIHvFTK
# downloading to /root/Downloads/Haystacks_Data/GA_LISTINGS_SALES.csv
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
df=pd.read_csv('/root/Downloads/Haystacks_Data/GA_LISTINGS_SALES_V2.csv')

# %%
df.head()
# Out:
#    Unnamed: 0   latitude  longitude       full_street_address       city  \
# 0           0  30.725605 -83.671772  0 Johnson Road #10026497    Quitman
# 1           1  30.781796 -83.558475          505 S Lee Street    Quitman
# 2           2  30.864096 -81.622765      33 River Oaks Street   Woodbine
# 3           3  30.796300 -81.681675     605 E Lawnwood Avenue  Kingsland
# 4           4  30.762972 -81.660240    84 Whippoorwill Circle  Kingsland
#
#      county_name  beds  baths_full  baths_half  square_footage  ...  \
# 0  Brooks-County   NaN         NaN         NaN             NaN  ...
# 1  Brooks-County   3.0         1.0         NaN          1460.0  ...
# 2  Camden-County   3.0         2.0         NaN          1254.0  ...
# 3  Camden-County   2.0         2.0         NaN          1016.0  ...
# 4  Camden-County   3.0         2.0         NaN          1618.0  ...
#
#                                    details  special_features unit_count  \
# 0                    Lots/Land, 4.93 Acres                 0        NaN
# 1    Detached, 3 Beds, 1 Bath, 1,460 Sq Ft                 0        NaN
# 2   Detached, 3 Beds, 2 Baths, 1,254 Sq Ft                 0        NaN
# 3  Townhouse, 2 Beds, 2 Baths, 1,016 Sq Ft                 0        NaN
# 4   Detached, 3 Beds, 2 Baths, 1,618 Sq Ft                 0        NaN
#
#     price  transaction_type  listing_status  listing_special_features  \
# 0   51900                 1               0                         0
# 1   99000                 1               1                         0
# 2  245816                 1               1                         0
# 3  155000                 1               1                         0
# 4  200000                 1               1                         0
#
#    census_state_name  census_county_name    zip
# 0            Georgia          Brooks, GA  31643
# 1            Georgia          Brooks, GA  31643
# 2            Georgia          Camden, GA  31569
# 3            Georgia          Camden, GA  31548
# 4            Georgia          Camden, GA  31548
#
# [5 rows x 22 columns]

# %%
# Drop first column of dataframe
df = df.iloc[: , 1:]

# %%
# strip property type from details feature column
df.details=df.details.str.split(',', expand=True)[[0]]

# %%
df.head()
# Out:
#     latitude  longitude       full_street_address       city    county_name  \
# 0  30.725605 -83.671772  0 Johnson Road #10026497    Quitman  Brooks-County
# 1  30.781796 -83.558475          505 S Lee Street    Quitman  Brooks-County
# 2  30.864096 -81.622765      33 River Oaks Street   Woodbine  Camden-County
# 3  30.796300 -81.681675     605 E Lawnwood Avenue  Kingsland  Camden-County
# 4  30.762972 -81.660240    84 Whippoorwill Circle  Kingsland  Camden-County
#
#    beds  baths_full  baths_half  square_footage  lot_size  ...    details  \
# 0   NaN         NaN         NaN             NaN       4.0  ...  Lots/Land
# 1   3.0         1.0         NaN          1460.0       0.0  ...   Detached
# 2   3.0         2.0         NaN          1254.0       0.0  ...   Detached
# 3   2.0         2.0         NaN          1016.0       0.0  ...  Townhouse
# 4   3.0         2.0         NaN          1618.0       0.0  ...   Detached
#
#   special_features  unit_count   price  transaction_type  listing_status  \
# 0                0         NaN   51900                 1               0
# 1                0         NaN   99000                 1               1
# 2                0         NaN  245816                 1               1
# 3                0         NaN  155000                 1               1
# 4                0         NaN  200000                 1               1
#
#    listing_special_features  census_state_name census_county_name    zip
# 0                         0            Georgia         Brooks, GA  31643
# 1                         0            Georgia         Brooks, GA  31643
# 2                         0            Georgia         Camden, GA  31569
# 3                         0            Georgia         Camden, GA  31548
# 4                         0            Georgia         Camden, GA  31548
#
# [5 rows x 21 columns]

# %%
# include only detached properties
df=df.loc[df['details']=='Detached']

# %%
# drop properties with zero square footage
df=df.loc[df['square_footage']!=0]

# %%
# reset index 
df=df.reset_index(drop=True)

# %%
for column in df:
    unique_vals = np.unique(df[column])
    nr_values = len(unique_vals)
    if nr_values < 10:
        print('The number of values for feature {} :{} -- {}'.format(column, nr_values,unique_vals))
    else:
        print('The number of values for feature {} :{}'.format(column, nr_values))
# Out:
# The number of values for feature latitude :10377
# The number of values for feature longitude :10315
# The number of values for feature full_street_address :11038
# The number of values for feature city :449
# The number of values for feature county_name :148
# The number of values for feature beds :18
# The number of values for feature baths_full :16
# The number of values for feature baths_half :11
# The number of values for feature square_footage :3436
# The number of values for feature lot_size :132
# The number of values for feature year_built :165
# The number of values for feature details :1 -- ['Detached']
# The number of values for feature special_features :8 -- [  0   1   2   3  20  64 512 514]
# The number of values for feature unit_count :14
# The number of values for feature price :2441
# The number of values for feature transaction_type :1 -- [1]
# The number of values for feature listing_status :2 -- [0 1]
# The number of values for feature listing_special_features :8 -- [  0   1   2   3  20  64 512 514]
# The number of values for feature census_state_name :1 -- ['Georgia']
# The number of values for feature census_county_name :148
# The number of values for feature zip :535

# %%
df.describe().T
# Out:
#                             count           mean            std          min  \
# latitude                  12206.0      33.590218       0.834537    30.361079
# longitude                 12206.0     -83.866255       0.987522   -85.502994
# beds                      12058.0       3.756096       1.305836     0.000000
# baths_full                11894.0       2.581806       1.277515     1.000000
# baths_half                 4867.0       1.111362       0.538231     0.000000
# square_footage            10474.0    2556.527401    1817.236042     1.000000
# lot_size                  11106.0      28.831352    1032.194826     0.000000
# year_built                12168.0    1987.859632      30.831242  1701.000000
# special_features          12206.0       5.437408      50.303405     0.000000
# unit_count                  149.0       3.684564       7.586517     1.000000
# price                     12206.0  597705.415369  892460.390475     1.000000
# transaction_type          12206.0       1.000000       0.000000     1.000000
# listing_status            12206.0       0.982468       0.131249     0.000000
# listing_special_features  12206.0       5.437408      50.303405     0.000000
#
#                                     25%            50%            75%  \
# latitude                      33.351920      33.779436      34.085610
# longitude                    -84.451997     -84.135132     -83.656075
# beds                           3.000000       4.000000       4.000000
# baths_full                     2.000000       2.000000       3.000000
# baths_half                     1.000000       1.000000       1.000000
# square_footage              1512.000000    2153.000000    3006.000000
# lot_size                       0.000000       0.000000       1.000000
# year_built                  1969.000000    1995.000000    2014.000000
# special_features               0.000000       0.000000       0.000000
# unit_count                     2.000000       2.000000       4.000000
# price                     280000.000000  400000.000000  607439.250000
# transaction_type               1.000000       1.000000       1.000000
# listing_status                 1.000000       1.000000       1.000000
# listing_special_features       0.000000       0.000000       0.000000
#
#                                    max
# latitude                  3.499197e+01
# longitude                -8.084255e+01
# beds                      7.100000e+01
# baths_full                5.600000e+01
# baths_half                1.000000e+01
# square_footage            4.128000e+04
# lot_size                  7.361600e+04
# year_built                2.023000e+03
# special_features          5.140000e+02
# unit_count                8.900000e+01
# price                     4.525000e+07
# transaction_type          1.000000e+00
# listing_status            1.000000e+00
# listing_special_features  5.140000e+02

# %%
df.isna().sum()
# Out:
# latitude                        0
# longitude                       0
# full_street_address             0
# city                            0
# county_name                     0
# beds                          148
# baths_full                    312
# baths_half                   7339
# square_footage               1732
# lot_size                     1100
# year_built                     38
# details                         0
# special_features                0
# unit_count                  12057
# price                           0
# transaction_type                0
# listing_status                  0
# listing_special_features        0
# census_state_name               0
# census_county_name              0
# zip                             0
# dtype: int64

# %%
features = [
       'beds', 'baths_full',
       'baths_half']

for f in features:
    sns.countplot(x = f, data = df, palette = 'Set3')
    plt.xticks(rotation=45)
    plt.show()

# %%
df.city.value_counts().head(10)
# Out:
# Atlanta          1153
# Savannah          458
# MacOn             307
# Marietta          285
# Lawrenceville     225
# Gainesville       211
# Dallas            203
# Decatur           195
# Cumming           184
# Loganville        166
# Name: city, dtype: int64

# %%
df.year_built.value_counts().head(10)
# Out:
# 2022.0    1621
# 2021.0     637
# 2006.0     303
# 2005.0     278
# 2004.0     242
# 1999.0     231
# 2000.0     226
# 2007.0     216
# 2001.0     213
# 1950.0     208
# Name: year_built, dtype: int64

# %%
# identify categorical data (ensure it is set to object type):
    #city
    #county_name
    #details (extract house type)
    #special features (probably categorical, convert to object type)
    #census_state_name 
    #census_county_name
    #zip 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12206 entries, 0 to 12205
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   latitude                  12206 non-null  float64
#  1   longitude                 12206 non-null  float64
#  2   full_street_address       12206 non-null  object
#  3   city                      12206 non-null  object
#  4   county_name               12206 non-null  object
#  5   beds                      12058 non-null  float64
#  6   baths_full                11894 non-null  float64
#  7   baths_half                4867 non-null   float64
#  8   square_footage            10474 non-null  float64
#  9   lot_size                  11106 non-null  float64
#  10  year_built                12168 non-null  float64
#  11  details                   12206 non-null  object
#  12  special_features          12206 non-null  int64
#  13  unit_count                149 non-null    float64
#  14  price                     12206 non-null  int64
#  15  transaction_type          12206 non-null  int64
#  16  listing_status            12206 non-null  int64
#  17  listing_special_features  12206 non-null  int64
#  18  census_state_name         12206 non-null  object
#  19  census_county_name        12206 non-null  object
#  20  zip                       12206 non-null  object
# dtypes: float64(9), int64(5), object(7)
# memory usage: 2.0+ MB

# %%
df['special_features'] = df['special_features'].astype(object)

#transaction_type ( this needs to be converted to object))
df['transaction_type'] = df['transaction_type'].astype(object)

#listing_status (convert to object)
df['listing_status'] = df['listing_status'].astype(object)
        
#listing_special_features (covert to object)
df['listing_special_features'] = df['listing_special_features'].astype(object)

# %%
df.shape
# Out:
# (12206, 21)

# %%
df.unit_count.value_counts()
# Out:
# 2.0     66
# 1.0     25
# 4.0     17
# 3.0     15
# 5.0     12
# 6.0      4
# 7.0      3
# 14.0     2
# 89.0     1
# 12.0     1
# 24.0     1
# 10.0     1
# 11.0     1
# Name: unit_count, dtype: int64

# %%
df.unit_count.isna().sum()
# Out:
# 12057

# %%
df.baths_half.value_counts()
# Out:
# 1.0     4319
# 2.0      331
# 0.0       99
# 3.0       83
# 4.0       19
# 5.0        9
# 10.0       3
# 6.0        2
# 9.0        1
# 7.0        1
# Name: baths_half, dtype: int64

# %%
df.baths_half.isna().sum()
# assuming that baths_half = 0 when missing?
# Out:
# 7339

# %%
df['baths_half'] = df['baths_half'].fillna(0)

# %%
# drop unit count columns with a majority null values
df=df.drop(['unit_count'], axis=1)

# %%
df.isna().sum()
# Out:
# latitude                       0
# longitude                      0
# full_street_address            0
# city                           0
# county_name                    0
# beds                         148
# baths_full                   312
# baths_half                     0
# square_footage              1732
# lot_size                    1100
# year_built                    38
# details                        0
# special_features               0
# price                          0
# transaction_type               0
# listing_status                 0
# listing_special_features       0
# census_state_name              0
# census_county_name             0
# zip                            0
# dtype: int64

# %%
df.square_footage.hist(bins=40)

# %%
df[df['square_footage'] < 500].shape
# Out:
# (43, 20)

# %%
df.special_features.value_counts()
# Out:
# 0      9290
# 2      2373
# 1       373
# 512     104
# 3        48
# 514      15
# 64        2
# 20        1
# Name: special_features, dtype: int64

# %%
df[['price','special_features']].groupby('special_features').mean()/1000
# Out:
#                         price
# special_features
# 0                  567.339472
# 1                  596.779676
# 2                  683.991290
# 3                  564.940500
# 20                  40.000000
# 64                  47.500000
# 512               1305.432913
# 514               1085.419067

# %%
##drop lot size
df=df.drop(['lot_size'], axis=1)

# %%
boxplot = df[['square_footage']].boxplot()

# %%
sns.boxplot(data=df, x="square_footage", hue="special_features")

# %%
sns.boxplot(x=np.log(df["square_footage"]))

# %%
# should we use log of square footage?

# %%
#df[df.square_footage < 500].square_footage = np.nan
df.loc[df['square_footage'] < 500, 'square_footage'] = np.nan

# %%
df[df.square_footage < 500].square_footage
# Out:
# Series([], Name: square_footage, dtype: float64)

# %%
sns.boxplot(x=df["price"])

# %%
sns.boxplot(x=np.log(df["price"]))

# %%
df.price.describe()
# Out:
# count    1.220600e+04
# mean     5.977054e+05
# std      8.924604e+05
# min      1.000000e+00
# 25%      2.800000e+05
# 50%      4.000000e+05
# 75%      6.074392e+05
# max      4.525000e+07
# Name: price, dtype: float64

# %%
df.price.isna().sum()
# Out:
# 0

# %%
df[df['price']>=300000].shape
# Out:
# (8624, 19)

# %%
df=df.loc[df['price']>=300000]

# %%
df[df['price']<=650000].shape
df=df.loc[df['price']<=650000]

# %%
df.shape
# Out:
# (5911, 19)

# %% [markdown]
# Impute Missing Values

# %%
# !pip install missingpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting missingpy
#   Downloading missingpy-0.2.0-py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 1.5 MB/s
# Installing collected packages: missingpy
# Successfully installed missingpy-0.2.0

# %%
import sklearn.neighbors._base
sys.modules['sklearn.neighbors.base'] = sklearn.neighbors._base

# %%
# Let X be an array containing missing values
#from missingpy import KNNImputer
#imputer = KNNImputer()
#imputer = KNNImputer(n_neighbors=5, weights="distance")
#X = np.array(df.beds).reshape(-1, 1)
#X_imputed = imputer.fit_transform(X)

# %%
df[df.beds.isna()]
# Out:
#         latitude  longitude                     full_street_address  \
# 111    31.775980 -82.349588                  [Address Not Provided]
# 881    32.403632 -81.774937    230 Lanier Drive #281-284 PARK PLACE
# 882    32.403632 -81.774937               230 Lanier Drive #277-280
# 928    32.453012 -81.778317                     1 N Mulberry Street
# 1174   33.625220 -85.131033             217 & 229 Little River Road
# 1334   32.024322 -81.078807                         2201 Walz Drive
# 2134   33.591875 -84.458281                     2048/2050 Banks Way
# 2235   34.072441 -84.526363  4919 Farmstead Court NE #4921 AND 4919
# 2336   33.815929 -84.626877                       2503 Brooks Drive
# 2751   33.986234 -84.482972                      2361 Hembree Drive
# 2852   33.803648 -84.555912              0 Venetian Way SW #9026591
# 2877   33.922778 -84.594586              0 Atlanta Road SE #8656029
# 3012   33.238696 -84.834097                    96&112 Arnold Street
# 3028   33.378333 -84.783658                       30 Bennett Street
# 3956   33.760384 -84.743301                    8036 Colquitt Street
# 4038   33.780210 -84.655003                  7178 S Sweetwater Road
# 4247   32.152205 -81.809817                   17992 U S Highway 280
# 4562   34.292370 -85.222481                  37 Crosscreek Drive NW
# 5194   33.676289 -84.419098                        2881 Sylvan Road
# 5386   33.722935 -84.401070                    1173 Smith Street SW
# 5387   33.720009 -84.556190                      1288 Elva Drive SW
# 5399   33.665508 -84.408981                        607 North Avenue
# 5416   33.663891 -84.406593                    3247 N Fulton Avenue
# 6041   33.748108 -84.367531                   607 Gaskill Street SE
# 7209   33.967495 -84.229510                   5871 Terrace Bend Way
# 7384   34.551350 -83.570572                 3789 Old Cleveland Road
# 7681   34.401421 -83.932716                         4917 Price Road
# 7710   34.329372 -83.814830                   5 & 3 Indianola Drive
# 7717   34.306773 -83.761979                        2808 Pierce Road
# 7881   34.382155 -82.895948                            103 Joy Lane
# 8091   33.507853 -84.234667    532-534 Oakwood Manor Drive #532 534
# 8255   33.427380 -84.089783                       49 S Bethany Road
# 10132  34.000890 -85.043251                        437 Hogue Avenue
# 10278  34.989217 -83.378904                           491 Lamb Road
# 10435  33.578983 -84.101044                        3445 Harper Road
# 10586  33.278994 -84.233305                       1540 N 2nd Street
# 10611  34.556488 -83.308060             132,148,162,164 Highway 123
# 11464  34.989217 -83.378904                           491 Lamb Road
# 11649  32.024322 -81.078807                         2201 Walz Drive
# 12017  34.551350 -83.570572                 3789 Old Cleveland Road
# 12070  34.382155 -82.895948                            103 Joy Lane
# 12153  34.989217 -83.378904                           491 Lamb Road
# 12189  34.556488 -83.308060             132,148,162,164 Highway 123
#
#                     city       county_name  beds  baths_full  baths_half  \
# 111               Baxley    Appling-County   NaN         NaN         0.0
# 881           Statesboro    Bulloch-County   NaN         NaN         0.0
# 882           Statesboro    Bulloch-County   NaN         NaN         0.0
# 928           Statesboro    Bulloch-County   NaN         NaN         0.0
# 1174          Carrollton    Carroll-County   NaN         NaN         0.0
# 1334            Savannah    Chatham-County   NaN         NaN         0.0
# 2134             Atlanta    Clayton-County   NaN         NaN         0.0
# 2235           Woodstock       Cobb-County   NaN         NaN         0.0
# 2336             Austell       Cobb-County   NaN         NaN         0.0
# 6041            Georgia         Fulton, GA  30316
# 7209            Georgia       Gwinnett, GA  30092
# 7384            Georgia      Habersham, GA  30531
# 7681            Georgia           Hall, GA  30506
# 7710            Georgia           Hall, GA  30501
# 7717            Georgia           Hall, GA  30507
# 7881            Georgia           Hart, GA  30643
# 8091            Georgia          Henry, GA  30281
# 8255            Georgia          Henry, GA  30252
# 10132           Georgia           Polk, GA  30153
# 10278           Georgia          Rabun, GA  30537
# 10435           Georgia       Rockdale, GA  30252
# 10586           Georgia       Spalding, GA  30223
# 10611           Georgia       Stephens, GA  30577
# 11464           Georgia          Rabun, GA  30537
# 11649           Georgia        Chatham, GA  31404
# 12017           Georgia      Habersham, GA  30531
# 12070           Georgia           Hart, GA  30643
# 12153           Georgia          Rabun, GA  30537
# 12189           Georgia       Stephens, GA  30577

# %%
df2 = df[['beds','baths_full','square_footage','year_built','price']]

# %% [markdown]
# # Using Random Forest to impute missing data

# %%
from missingpy import MissForest
imputer = MissForest() #miss forest
X_imputed = imputer.fit_transform(df2)
X_imputed = pd.DataFrame(X_imputed, columns = df2.columns).round(1)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/_forest.py:400: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/_forest.py:400: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/_forest.py:400: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/_forest.py:400: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   FutureWarning,
# Iteration: 0
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/_forest.py:400: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/_forest.py:400: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/_forest.py:400: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/_forest.py:400: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   FutureWarning,
# Iteration: 1
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/_forest.py:400: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/_forest.py:400: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/_forest.py:400: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/_forest.py:400: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   FutureWarning,
# Iteration: 2
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/_forest.py:400: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/_forest.py:400: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/_forest.py:400: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/_forest.py:400: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   FutureWarning,
# Iteration: 3
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/_forest.py:400: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/_forest.py:400: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/_forest.py:400: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/_forest.py:400: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   FutureWarning,
# Iteration: 4

# %%
X_imputed.shape
# Out:
# (5911, 5)

# %%
X_imputed.isna().sum()
# Out:
# beds              0
# baths_full        0
# square_footage    0
# year_built        0
# price             0
# dtype: int64

# %%
df['beds_imputed'] = df['beds'].fillna(X_imputed['beds'])
df['baths_full_imputed'] = df['baths_full'].fillna(X_imputed['baths_full'])
df['year_built_imputed'] = df['year_built'].fillna(X_imputed['year_built'])
df['square_footage_imputed'] = df['square_footage'].fillna(X_imputed['square_footage'])

# %%
df.isna().sum()
# Out:
# latitude                      0
# longitude                     0
# full_street_address           0
# city                          0
# county_name                   0
# beds                         43
# baths_full                  102
# baths_half                    0
# square_footage              771
# year_built                   15
# details                       0
# special_features              0
# price                         0
# transaction_type              0
# listing_status                0
# listing_special_features      0
# census_state_name             0
# census_county_name            0
# zip                           0
# beds_imputed                 20
# baths_full_imputed           59
# year_built_imputed           13
# square_footage_imputed      474
# dtype: int64

# %%
df[df['beds'] != df['beds_imputed']].shape
# Out:
# (43, 23)

# %%
df[df['baths_full'] != df['baths_full_imputed']].shape
# Out:
# (102, 23)

# %%
df[df['year_built'] != df['year_built_imputed']].shape
# Out:
# (15, 23)

# %%
df.drop(['beds','baths_full','year_built', 'square_footage'],inplace=True,axis=1)

# %%
df.rename(columns={"beds_imputed": "beds", "baths_full_imputed": "baths_full",
                   "year_built_imputed": "year_built", 
                   "square_footage_imputed":"square_footage"}, inplace=True)

# %%
df.head()
# Out:
#      latitude  longitude           full_street_address         city  \
# 3   30.804209 -81.653325            101 College Street    Kingsland
# 6   30.767365 -81.588272  169 School House Creek Drive  Saint Marys
# 7   30.746731 -81.633995          1621 Sandpiper Court  Saint Marys
# 13  30.791878 -81.676750  346 Laurel Landing Boulevard    Kingsland
# 14  31.104492 -81.604486                81 Ossabaw Way      Waverly
#
#       county_name  baths_half   details special_features   price  \
# 3   Camden-County         0.0  Detached                2  339900
# 6   Camden-County         0.0  Detached                0  310000
# 7   Camden-County         0.0  Detached                0  315000
# 13  Camden-County         0.0  Detached                0  310000
# 14  Camden-County         0.0  Detached                2  369900
#
#    transaction_type listing_status listing_special_features census_state_name  \
# 3                 1              1                        2           Georgia
# 6                 1              1                        0           Georgia
# 7                 1              1                        0           Georgia
# 13                1              1                        0           Georgia
# 14                1              1                        2           Georgia
#
#    census_county_name    zip  beds  baths_full  year_built  square_footage
# 3          Camden, GA  31548   4.0         2.0      2020.0          2103.0
# 6          Camden, GA  31558   5.0         3.0      2004.0          2269.0
# 7          Camden, GA  31558   3.0         2.0      2004.0          1846.0
# 13         Camden, GA  31548   3.0         2.0      2017.0          1977.0
# 14         Camden, GA  31565   3.0         2.0      2022.0          1835.0

# %%
#df.to_csv('out.csv', index=False)

# %%
df.isna().sum()
# Out:
# latitude                      0
# longitude                     0
# full_street_address           0
# city                          0
# county_name                   0
# baths_half                    0
# details                       0
# special_features              0
# price                         0
# transaction_type              0
# listing_status                0
# listing_special_features      0
# census_state_name             0
# census_county_name            0
# zip                           0
# beds                         20
# baths_full                   59
# year_built                   13
# square_footage              474
# dtype: int64

# %%
# save a list of categorical cols
cats=[]
for col in df.columns:
  if df[col].dtype=='object':
    cats.append(col)

# %%
# save a list of numerical cols
numers=[]
for col in df.columns:
  if df[col].dtype==('float64') or df[col].dtype==('int64'):
    numers.append(col)

# %%
cats
# Out:
# ['full_street_address',
#  'city',
#  'county_name',
#  'details',
#  'special_features',
#  'transaction_type',
#  'listing_status',
#  'listing_special_features',
#  'census_state_name',
#  'census_county_name',
#  'zip']

# %%
numers
# Out:
# ['latitude',
#  'longitude',
#  'baths_half',
#  'price',
#  'beds',
#  'baths_full',
#  'year_built',
#  'square_footage']

# %%
sns.scatterplot(data=df, x='square_footage', y='price')

# %%
df[df['square_footage']>30000]
# Out:
# Empty DataFrame
# Columns: [latitude, longitude, full_street_address, city, county_name, baths_half, details, special_features, price, transaction_type, listing_status, listing_special_features, census_state_name, census_county_name, zip, beds, baths_full, year_built, square_footage]
# Index: []

# %% [markdown]
# # Merging the HPI Data

# %%
hpi = pd.read_csv('/root/Downloads/Haystacks_Data/zip5_hpi.csv')

# %%
hpi.head()
# Out:
#    ZipCode   Y2020   Y2021
# 0     1001  297.85  331.21
# 1     1002  424.18  455.47
# 2     1005  206.43  247.43
# 3     1007  318.44  349.00
# 4     1008  143.35  158.84

# %%
#hpi.pct_change(axis='columns', periods=-1)
hpi['PCT_CHG'] = (hpi['Y2021'] / hpi['Y2020'] - 1).fillna(0)

# %%
hpi.replace([np.inf, -np.inf], 0, inplace=True)

# %%
hpi['PCT_CHG'].min()
# Out:
# -1.0

# %%
val = hpi[hpi['PCT_CHG'] > 0].PCT_CHG.mean(axis=0, skipna=True)

# %%
hpi.loc[hpi['PCT_CHG'] <= 0, 'PCT_CHG'] = val

# %%
hpi.PCT_CHG.max()
# Out:
# 0.6390828278203806

# %%
hpi.head()
# Out:
#    ZipCode   Y2020   Y2021   PCT_CHG
# 0     1001  297.85  331.21  0.112003
# 1     1002  424.18  455.47  0.073766
# 2     1005  206.43  247.43  0.198615
# 3     1007  318.44  349.00  0.095968
# 4     1008  143.35  158.84  0.108057

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5911 entries, 3 to 12205
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   latitude                  5911 non-null   float64
#  1   longitude                 5911 non-null   float64
#  2   full_street_address       5911 non-null   object
#  3   city                      5911 non-null   object
#  4   county_name               5911 non-null   object
#  5   baths_half                5911 non-null   float64
#  6   details                   5911 non-null   object
#  7   special_features          5911 non-null   object
#  8   price                     5911 non-null   int64
#  9   transaction_type          5911 non-null   object
#  10  listing_status            5911 non-null   object
#  11  listing_special_features  5911 non-null   object
#  12  census_state_name         5911 non-null   object
#  13  census_county_name        5911 non-null   object
#  14  zip                       5911 non-null   object
#  15  beds                      5891 non-null   float64
#  16  baths_full                5852 non-null   float64
#  17  year_built                5898 non-null   float64
#  18  square_footage            5437 non-null   float64
# dtypes: float64(7), int64(1), object(11)
# memory usage: 923.6+ KB

# %%
df['zip'] = df['zip'].astype(str).astype(int)

# %%
#df2.drop(['ZipCode', 'Y2020','Y2021','PCT_CHG'], axis=1, inplace=True)

# %%
df2.head()
# Out:
#     beds  baths_full  square_footage  year_built   price
# 3    4.0         2.0          2103.0      2020.0  339900
# 6    5.0         3.0          2269.0      2004.0  310000
# 7    3.0         2.0          1846.0      2004.0  315000
# 13   3.0         2.0          1977.0      2017.0  310000
# 14   3.0         2.0          1835.0      2022.0  369900

# %%
df2 = pd.merge(df,hpi, how = "left", left_on="zip", right_on="ZipCode")

# %%
df2.head()
# Out:
#     latitude  longitude           full_street_address         city  \
# 0  30.804209 -81.653325            101 College Street    Kingsland
# 1  30.767365 -81.588272  169 School House Creek Drive  Saint Marys
# 2  30.746731 -81.633995          1621 Sandpiper Court  Saint Marys
# 3  30.791878 -81.676750  346 Laurel Landing Boulevard    Kingsland
# 4  31.104492 -81.604486                81 Ossabaw Way      Waverly
#
#      county_name  baths_half   details special_features   price  \
# 0  Camden-County         0.0  Detached                2  339900
# 1  Camden-County         0.0  Detached                0  310000
# 2  Camden-County         0.0  Detached                0  315000
# 3  Camden-County         0.0  Detached                0  310000
# 4  Camden-County         0.0  Detached                2  369900
#
#   transaction_type  ... census_county_name    zip beds baths_full  year_built  \
# 0                1  ...         Camden, GA  31548  4.0        2.0      2020.0
# 1                1  ...         Camden, GA  31558  5.0        3.0      2004.0
# 2                1  ...         Camden, GA  31558  3.0        2.0      2004.0
# 3                1  ...         Camden, GA  31548  3.0        2.0      2017.0
# 4                1  ...         Camden, GA  31565  3.0        2.0      2022.0
#
#    square_footage  ZipCode   Y2020   Y2021   PCT_CHG
# 0          2103.0  31548.0  202.90  226.83  0.117940
# 1          2269.0  31558.0  237.93  265.03  0.113899
# 2          1846.0  31558.0  237.93  265.03  0.113899
# 3          1977.0  31548.0  202.90  226.83  0.117940
# 4          1835.0  31565.0  129.63  132.31  0.020674
#
# [5 rows x 23 columns]

# %% [markdown]
# found a bug with float not taking replace nan

# %%
df2.PCT_CHG.isna().sum()
# Out:
# 64

# %%
val = df2[['PCT_CHG']].mean(axis=0, skipna=True)
print(val)
# Out:
# PCT_CHG    0.142744
# dtype: float64

# %%
df2['PCT_CHG'].fillna(value=val, inplace=True)

# %%
df2.PCT_CHG.isna().sum()
# Out:
# 64

# %%
df2.loc[df2['PCT_CHG'].isna(), 'PCT_CHG'] = 0

# %%
df2.loc[df2['PCT_CHG'] == 0, 'PCT_CHG'] = 0.138411

# %%
df2.head()
# Out:
#     latitude  longitude           full_street_address         city  \
# 0  30.804209 -81.653325            101 College Street    Kingsland
# 1  30.767365 -81.588272  169 School House Creek Drive  Saint Marys
# 2  30.746731 -81.633995          1621 Sandpiper Court  Saint Marys
# 3  30.791878 -81.676750  346 Laurel Landing Boulevard    Kingsland
# 4  31.104492 -81.604486                81 Ossabaw Way      Waverly
#
#      county_name  baths_half   details special_features   price  \
# 0  Camden-County         0.0  Detached                2  339900
# 1  Camden-County         0.0  Detached                0  310000
# 2  Camden-County         0.0  Detached                0  315000
# 3  Camden-County         0.0  Detached                0  310000
# 4  Camden-County         0.0  Detached                2  369900
#
#   transaction_type  ... census_county_name    zip beds baths_full  year_built  \
# 0                1  ...         Camden, GA  31548  4.0        2.0      2020.0
# 1                1  ...         Camden, GA  31558  5.0        3.0      2004.0
# 2                1  ...         Camden, GA  31558  3.0        2.0      2004.0
# 3                1  ...         Camden, GA  31548  3.0        2.0      2017.0
# 4                1  ...         Camden, GA  31565  3.0        2.0      2022.0
#
#    square_footage  ZipCode   Y2020   Y2021   PCT_CHG
# 0          2103.0  31548.0  202.90  226.83  0.117940
# 1          2269.0  31558.0  237.93  265.03  0.113899
# 2          1846.0  31558.0  237.93  265.03  0.113899
# 3          1977.0  31548.0  202.90  226.83  0.117940
# 4          1835.0  31565.0  129.63  132.31  0.020674
#
# [5 rows x 23 columns]

# %%
df2.drop(['ZipCode', 'Y2020','Y2021'], axis=1, inplace=True)

# %%
tax = pd.read_csv('/root/Downloads/Haystacks_Data/ga_tax_data.csv')

# %%
tax.shape
# Out:
# (5334, 23)

# %%
tax.head(10)
# Out:
#        ZIP              gross_range  Individuals_taxed  Elderly_taxed  \
# 0      0.0         $1 under $25,000          2541970.0       263720.0
# 1      0.0    $25,000 under $50,000          2185530.0       199930.0
# 2      0.0    $50,000 under $75,000          1265460.0       153930.0
# 3      0.0   $75,000 under $100,000           872360.0       112580.0
# 4      0.0  $100,000 under $200,000          1515900.0       178900.0
# 5      0.0         $200,000 or more           680510.0        68090.0
# 6      NaN                      NaN                NaN            NaN
# 7  30002.0                      NaN             5630.0          830.0
# 8  30002.0         $1 under $25,000             1100.0          170.0
# 9  30002.0    $25,000 under $50,000              940.0          130.0
#
#      Total_AGI  Number_of_returns  Total_income  Income_per_return  \
# 0   22022473.0          1721510.0    22466321.0          13.050358
# 1   41270125.0          1144020.0    41745495.0          36.490179
# 2   38156316.0           621540.0    38568414.0          62.052988
# 3   32849922.0           379220.0    33138688.0          87.386446
# 4   79560233.0           580760.0    80297769.0         138.263257
# 5  111878646.0           234090.0   113142494.0         483.329036
# 6          NaN                NaN           NaN                NaN
# 7     311795.0             3220.0      316275.0          98.222050
# 8      11212.0              860.0       11572.0          13.455814
# 9      24007.0              660.0       24316.0          36.842424
#
#    Int_Number of returns  Int_Amount  ...  UE_claims  Social_security  \
# 0               159830.0    118926.0  ...   2.650756         2.175708
# 1               156280.0    145730.0  ...   2.394631         7.129061
# 2               155560.0    166725.0  ...   2.642868        15.733585
# 3               133680.0    171524.0  ...   2.791194        20.959103
# 4               288490.0    491388.0  ...   3.221080        25.522051
# 5               178130.0   1508755.0  ...   3.580000        29.935369
# 6                    NaN         NaN  ...        NaN              NaN
# 7                 1160.0      2133.0  ...   3.380000        18.939130
# 8                  120.0       107.0  ...   3.166667         2.925000
# 9                  110.0        76.0  ...        NaN         9.185714
#
#     SB_income  Student_loan_ded  RE_taxes  PP_taxes  Mortgage_Int_paid  \
# 0    1.711000          0.925326  3.046695  0.515131           8.187611
# 1    7.932646          1.063708  2.735561  0.795341           7.237558
# 2   13.876696          1.252795  2.895932  0.640170           7.632109
# 3   18.668958          1.121955  3.250570  0.575786           8.407577
# 4   32.003616          1.218707  4.147170  0.549020          10.550146
# 5  229.043267               NaN  8.153561  0.592897          16.051146
# 6         NaN               NaN       NaN       NaN                NaN
# 7   72.596429          1.075758  6.155714  0.393750          11.932258
# 8    3.375000          0.766667       NaN       NaN                NaN
# 9         NaN          1.188889  3.166667  0.333333           7.060000
#
#    Taxable_inc  Child_credit  Earned_Inc_credit
# 0     5.108415      0.342169           2.894770
# 1    19.037843      1.197139           2.351768
# 2    41.811811      2.273538           0.483000
# 3    63.933145      2.689675                NaN
# 4   110.207559      2.797180                NaN
# 5   416.463547      2.902940                NaN
# 6          NaN           NaN                NaN
# 7    90.082482      2.174667           2.242222
# 8     5.430769      0.366667           2.294118
# 9    21.078462      1.071429           2.081818
#
# [10 rows x 23 columns]

# %%
tax = tax[tax['ZIP'] > 0]

# %%
tax = tax[tax['gross_range'].isna()]

# %%
tax.isna().sum()
# Out:
# ZIP                        0
# gross_range              666
# Individuals_taxed          0
# Elderly_taxed              0
# Total_AGI                  0
# Number_of_returns          0
# Total_income               0
# Income_per_return          0
# Int_Number of returns      0
# Int_Amount                 0
# Int_earned                 4
# Cap_gain                  32
# Pension                    3
# UE_claims                167
# Social_security            3
# SB_income                113
# Student_loan_ded          71
# RE_taxes                  72
# PP_taxes                 124
# Mortgage_Int_paid         90
# Taxable_inc                0
# Child_credit               1
# Earned_Inc_credit          1
# dtype: int64

# %%
tax.drop(columns=['gross_range'], inplace = True)

# %%
tax = tax.fillna(0)

# %%
df2.shape
# Out:
# (5911, 20)

# %%
df3 = pd.merge(df2,tax, how = "left", left_on="zip", right_on="ZIP")

# %%
df3.shape
# Out:
# (5911, 42)

# %%
df3.head()
# Out:
#     latitude  longitude           full_street_address         city  \
# 0  30.804209 -81.653325            101 College Street    Kingsland
# 1  30.767365 -81.588272  169 School House Creek Drive  Saint Marys
# 2  30.746731 -81.633995          1621 Sandpiper Court  Saint Marys
# 3  30.791878 -81.676750  346 Laurel Landing Boulevard    Kingsland
# 4  31.104492 -81.604486                81 Ossabaw Way      Waverly
#
#      county_name  baths_half   details special_features   price  \
# 0  Camden-County         0.0  Detached                2  339900
# 1  Camden-County         0.0  Detached                0  310000
# 2  Camden-County         0.0  Detached                0  315000
# 3  Camden-County         0.0  Detached                0  310000
# 4  Camden-County         0.0  Detached                2  369900
#
#   transaction_type  ... UE_claims Social_security  SB_income Student_loan_ded  \
# 0                1  ...  3.546154       12.728319  36.895652         1.067021
# 1                1  ...  3.477778       17.108497  46.670968         1.004819
# 2                1  ...  3.477778       17.108497  46.670968         1.004819
# 3                1  ...  3.546154       12.728319  36.895652         1.067021
# 4                1  ...  0.000000       17.610526  65.228571         1.160000
#
#    RE_taxes  PP_taxes  Mortgage_Int_paid  Taxable_inc  Child_credit  \
# 0  3.122857  0.676744           8.708955    43.969231      2.125743
# 1  4.105556  0.758537          10.493939    50.748133      2.175097
# 2  4.105556  0.758537          10.493939    50.748133      2.175097
# 3  3.122857  0.676744           8.708955    43.969231      2.125743
# 4  4.311111  0.400000          10.333333    58.208108      1.936000
#
#    Earned_Inc_credit
# 0           2.585463
# 1           2.555497
# 2           2.555497
# 3           2.585463
# 4           2.294118
#
# [5 rows x 42 columns]

# %%
df3.isna().sum()
# Out:
# latitude                      0
# longitude                     0
# full_street_address           0
# city                          0
# county_name                   0
# baths_half                    0
# details                       0
# special_features              0
# price                         0
# transaction_type              0
# listing_status                0
# listing_special_features      0
# census_state_name             0
# census_county_name            0
# zip                           0
# beds                         20
# baths_full                   59
# year_built                   13
# square_footage              474
# PCT_CHG                       0
# ZIP                           5
# Individuals_taxed             5
# Elderly_taxed                 5
# Total_AGI                     5
# Number_of_returns             5
# Total_income                  5
# Income_per_return             5
# Int_Number of returns         5
# Int_Amount                    5
# Int_earned                    5
# Cap_gain                      5
# Pension                       5
# UE_claims                     5
# Social_security               5
# SB_income                     5
# Student_loan_ded              5
# RE_taxes                      5
# PP_taxes                      5
# Mortgage_Int_paid             5
# Taxable_inc                   5
# Child_credit                  5
# Earned_Inc_credit             5
# dtype: int64

# %%
pd.set_option('display.max_columns', None)
df3[df3.ZIP.isna()].census_county_name.unique()
# Out:
# array(['Baldwin, GA', 'Clayton, GA', 'DeKalb, GA', 'Evans, GA',
#        'Gordon, GA'], dtype=object)

# %%
df4 = df3[df3.census_county_name.isin(['Baldwin, GA', 'Clayton, GA', 'DeKalb, GA', 'Evans, GA',
                            'Fulton, GA', 'Gordon, GA', 'Morgan, GA', 'Rabun, GA', 'Wilcox, GA'])]

# %%
df4.dropna(inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
df4.shape
# Out:
# (1070, 42)

# %%
df4.columns
# Out:
# Index(['latitude', 'longitude', 'full_street_address', 'city', 'county_name',
#        'baths_half', 'details', 'special_features', 'price',
#        'transaction_type', 'listing_status', 'listing_special_features',
#        'census_state_name', 'census_county_name', 'zip', 'beds', 'baths_full',
#        'year_built', 'square_footage', 'PCT_CHG', 'ZIP', 'Individuals_taxed',
#        'Elderly_taxed', 'Total_AGI', 'Number_of_returns', 'Total_income',
#        'Income_per_return', 'Int_Number of returns', 'Int_Amount',
#        'Int_earned', 'Cap_gain', 'Pension', 'UE_claims', 'Social_security',
#        'SB_income', 'Student_loan_ded', 'RE_taxes', 'PP_taxes',
#        'Mortgage_Int_paid', 'Taxable_inc', 'Child_credit',
#        'Earned_Inc_credit'],
#       dtype='object')

# %%
df5 = df4[['census_county_name','Individuals_taxed',
       'Elderly_taxed', 'Total_AGI', 'Number_of_returns', 'Total_income',
       'Income_per_return', 'Int_Number of returns', 'Int_Amount',
       'Int_earned', 'Cap_gain', 'Pension', 'UE_claims', 'Social_security',
       'SB_income', 'Student_loan_ded', 'RE_taxes', 'PP_taxes',
       'Mortgage_Int_paid', 'Taxable_inc', 'Child_credit',
       'Earned_Inc_credit']].groupby('census_county_name').mean().reset_index()

# %%
df5
# Out:
#   census_county_name  Individuals_taxed  Elderly_taxed     Total_AGI  \
# 0        Baldwin, GA       28940.000000    4150.000000  7.761470e+05
# 1        Clayton, GA       35980.000000    3147.654321  8.347914e+05
# 2         DeKalb, GA       32644.779412    3389.509804  1.225141e+06
# 3          Evans, GA        8240.000000     940.000000  1.742200e+05
# 4         Fulton, GA       33325.319635    3033.150685  1.303658e+06
# 5         Gordon, GA       20434.500000    1835.500000  5.147448e+05
# 6         Morgan, GA       10223.611111    1375.000000  3.628993e+05
# 7          Rabun, GA        3806.250000     715.000000  1.222421e+05
#
#    Number_of_returns  Total_income  Income_per_return  Int_Number of returns  \
# 0       15740.000000  7.851900e+05          49.885006            3710.000000
# 1       19196.543210  8.431440e+05          43.134414            2306.172840
# 2       18499.656863  1.240348e+06          70.966975            3716.715686
# 3        4060.000000  1.759710e+05          43.342611             830.000000
# 4       18641.027397  1.319057e+06          63.917287            3519.132420
# 5        9855.500000  5.188580e+05          52.170040            1702.500000
# 6        5096.388889  3.673953e+05          72.993208            1428.611111
# 7        2043.750000  1.236574e+05          61.906183             620.000000
#
#     Int_Amount  Int_earned   Cap_gain    Pension  UE_claims  Social_security  \
# 0  5939.000000    1.600809  12.244048  31.444872   2.400000        16.225347
# 1  2887.629630    1.044002   7.622835  23.665424   2.947056        12.524327
# 2  8057.522059    1.512558  14.560388  26.045212   3.122936        14.671696
# 3  1315.000000    1.584337   9.723333  25.471233   2.983333        12.645283
# 4  8193.739726    1.375101  14.760669  25.009890   3.119003        13.143492
# 5  2879.800000    1.403663  12.846011  21.940842   1.263421        13.751967
# 6  4041.972222    2.659912  23.733388  31.037104   2.330903        16.944596
# 7  1642.250000    2.388863  18.944720  29.313701   0.681250        16.946583
#
#    SB_income  Student_loan_ded  RE_taxes  PP_taxes  Mortgage_Int_paid  \
# 0  56.319643          1.086735  3.078182  0.582500           8.764583
# 1  38.085733          1.144945  2.967929  0.751572           7.186222
# 2  51.536793          1.175414  4.107505  0.595451           9.405318
# 3  36.336842          1.110526  2.906250  0.480000           7.933333
# 4  52.753823          1.189153  3.778837  0.599773           9.808424
# 5  53.929763          1.028576  2.870147  0.434500           8.849775
# 6  56.183325          1.133320  4.362131  0.471359          11.438976
# 7  34.289315          1.134093  4.497073  0.266667          11.745463
#
#    Taxable_inc  Child_credit  Earned_Inc_credit
# 0    44.641130      1.483191           2.939588
# 1    35.238102      1.453735           2.840037
# 2    64.568548      1.676855           2.541922
# 3    37.806406      1.698182           2.851493
# 4    58.755144      1.493198           2.755829
# 5    43.817554      1.940202           2.541815
# 6    67.245800      2.010108           2.709823
# 7    57.153279      1.671890           2.456613

# %%
df6 = df3[df3.ZIP.isna()]

# %%
df6
# Out:
#        latitude  longitude          full_street_address           city  \
# 61    33.060680 -83.275668               886 Georgia 49  Milledgeville
# 947   33.435785 -84.316520  2293 Church Street #LOT 14B        Lovejoy
# 1579  33.789535 -84.204339             492 Spruce Drive      Pine Lake
# 2113  32.155917 -81.933143         5736 Tattnall Street          Hagan
# 2940  34.421800 -84.932000     516 Adare Parkway #LOT 4    Adairsville
#
#          county_name  baths_half   details special_features   price  \
# 61    Baldwin-County         1.0  Detached                0  495000
# 947   Clayton-County         1.0  Detached                2  357990
# 1579   DeKalb-County         0.0  Detached                0  395000
# 2113    Evans-County         0.0  Detached                0  500000
# 2940   Gordon-County         1.0  Detached                2  380990
#
#      transaction_type listing_status listing_special_features  \
# 61                  1              1                        0
# 947                 1              1                        2
# 1579                1              1                        0
# 2113                1              1                        0
# 2940                1              1                        2
#
#      census_state_name census_county_name    zip  beds  baths_full  \
# 61             Georgia        Baldwin, GA  31062   4.0         4.0
# 947            Georgia        Clayton, GA  30250   4.0         2.0
# 1579           Georgia         DeKalb, GA  30072   2.0         2.0
# 2113           Georgia          Evans, GA  30429   4.0         2.0
# 2940           Georgia         Gordon, GA  30301   4.0         3.0
#
#       year_built  square_footage   PCT_CHG  ZIP  Individuals_taxed  \
# 61        1998.0          1344.0  0.138411  NaN                NaN
# 947       2022.0          2161.0  0.138411  NaN                NaN
# 1579      1950.0          1454.0  0.138411  NaN                NaN
# 2113      1999.0          2552.0  0.138411  NaN                NaN
# 2940      2022.0          2770.0  0.138411  NaN                NaN
#
#       Elderly_taxed  Total_AGI  Number_of_returns  Total_income  \
# 61              NaN        NaN                NaN           NaN
# 947             NaN        NaN                NaN           NaN
# 1579            NaN        NaN                NaN           NaN
# 2113            NaN        NaN                NaN           NaN
# 2940            NaN        NaN                NaN           NaN
#
#       Income_per_return  Int_Number of returns  Int_Amount  Int_earned  \
# 61                  NaN                    NaN         NaN         NaN
# 947                 NaN                    NaN         NaN         NaN
# 1579                NaN                    NaN         NaN         NaN
# 2113                NaN                    NaN         NaN         NaN
# 2940                NaN                    NaN         NaN         NaN
#
#       Cap_gain  Pension  UE_claims  Social_security  SB_income  \
# 61         NaN      NaN        NaN              NaN        NaN
# 947        NaN      NaN        NaN              NaN        NaN
# 1579       NaN      NaN        NaN              NaN        NaN
# 2113       NaN      NaN        NaN              NaN        NaN
# 2940       NaN      NaN        NaN              NaN        NaN
#
#       Student_loan_ded  RE_taxes  PP_taxes  Mortgage_Int_paid  Taxable_inc  \
# 61                 NaN       NaN       NaN                NaN          NaN
# 947                NaN       NaN       NaN                NaN          NaN
# 1579               NaN       NaN       NaN                NaN          NaN
# 2113               NaN       NaN       NaN                NaN          NaN
# 2940               NaN       NaN       NaN                NaN          NaN
#
#       Child_credit  Earned_Inc_credit
# 61             NaN                NaN
# 947            NaN                NaN
# 1579           NaN                NaN
# 2113           NaN                NaN
# 2940           NaN                NaN

# %%
df6.drop(columns=['Individuals_taxed',
       'Elderly_taxed', 'Total_AGI', 'Number_of_returns', 'Total_income',
       'Income_per_return', 'Int_Number of returns', 'Int_Amount',
       'Int_earned', 'Cap_gain', 'Pension', 'UE_claims', 'Social_security',
       'SB_income', 'Student_loan_ded', 'RE_taxes', 'PP_taxes',
       'Mortgage_Int_paid', 'Taxable_inc', 'Child_credit',
       'Earned_Inc_credit'], inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df6.shape
# Out:
# (5, 21)

# %%
df7 = pd.merge(df6, df5, how="inner", on="census_county_name")

# %%
df7.shape
# Out:
# (5, 42)

# %%
df3.shape
# Out:
# (5911, 42)

# %%
tax_clean_df = df3.dropna()

# %%
tax_clean_df.shape
# Out:
# (5392, 42)

# %%
tax_clean_df = pd.concat([tax_clean_df, df7], ignore_index=True)

# %%
tax_clean_df.isna().sum()
# Out:
# latitude                    0
# longitude                   0
# full_street_address         0
# city                        0
# county_name                 0
# baths_half                  0
# details                     0
# special_features            0
# price                       0
# transaction_type            0
# listing_status              0
# listing_special_features    0
# census_state_name           0
# census_county_name          0
# zip                         0
# beds                        0
# baths_full                  0
# year_built                  0
# square_footage              0
# PCT_CHG                     0
# ZIP                         5
# Individuals_taxed           0
# Elderly_taxed               0
# Total_AGI                   0
# Number_of_returns           0
# Total_income                0
# Income_per_return           0
# Int_Number of returns       0
# Int_Amount                  0
# Int_earned                  0
# Cap_gain                    0
# Pension                     0
# UE_claims                   0
# Social_security             0
# SB_income                   0
# Student_loan_ded            0
# RE_taxes                    0
# PP_taxes                    0
# Mortgage_Int_paid           0
# Taxable_inc                 0
# Child_credit                0
# Earned_Inc_credit           0
# dtype: int64

# %%
tax_clean_df = tax_clean_df.drop(columns = ['ZIP'])

# %%
tax_clean_df.shape
# Out:
# (5397, 41)

# %%
tax_clean_df.head()
# Out:
#     latitude  longitude           full_street_address         city  \
# 0  30.804209 -81.653325            101 College Street    Kingsland
# 1  30.767365 -81.588272  169 School House Creek Drive  Saint Marys
# 2  30.746731 -81.633995          1621 Sandpiper Court  Saint Marys
# 3  30.791878 -81.676750  346 Laurel Landing Boulevard    Kingsland
# 4  31.104492 -81.604486                81 Ossabaw Way      Waverly
#
#      county_name  baths_half   details special_features   price  \
# 0  Camden-County         0.0  Detached                2  339900
# 1  Camden-County         0.0  Detached                0  310000
# 2  Camden-County         0.0  Detached                0  315000
# 3  Camden-County         0.0  Detached                0  310000
# 4  Camden-County         0.0  Detached                2  369900
#
#   transaction_type listing_status listing_special_features census_state_name  \
# 0                1              1                        2           Georgia
# 1                1              1                        0           Georgia
# 2                1              1                        0           Georgia
# 3                1              1                        0           Georgia
# 4                1              1                        2           Georgia
#
#   census_county_name    zip  beds  baths_full  year_built  square_footage  \
# 0         Camden, GA  31548   4.0         2.0      2020.0          2103.0
# 1         Camden, GA  31558   5.0         3.0      2004.0          2269.0
# 2         Camden, GA  31558   3.0         2.0      2004.0          1846.0
# 3         Camden, GA  31548   3.0         2.0      2017.0          1977.0
# 4         Camden, GA  31565   3.0         2.0      2022.0          1835.0
#
#     PCT_CHG  Individuals_taxed  Elderly_taxed  Total_AGI  Number_of_returns  \
# 0  0.117940            20160.0         1820.0   511435.0             9720.0
# 1  0.113899            18840.0         2230.0   553832.0             9270.0
# 2  0.113899            18840.0         2230.0   553832.0             9270.0
# 3  0.117940            20160.0         1820.0   511435.0             9720.0
# 4  0.020674             1800.0          280.0    61680.0              930.0
#
#    Total_income  Income_per_return  Int_Number of returns  Int_Amount  \
# 0      515826.0          53.068519                 2170.0      1616.0
# 1      558674.0          60.266882                 2500.0      3254.0
# 2      558674.0          60.266882                 2500.0      3254.0
# 3      515826.0          53.068519                 2170.0      1616.0
# 4       62196.0          66.877419                  290.0       475.0
#
#    Int_earned   Cap_gain    Pension  UE_claims  Social_security  SB_income  \
# 0    0.744700   6.500000  25.879817   3.546154        12.728319  36.895652
# 1    1.301600  17.274138  29.575630   3.477778        17.108497  46.670968
# 2    1.301600  17.274138  29.575630   3.477778        17.108497  46.670968
# 3    0.744700   6.500000  25.879817   3.546154        12.728319  36.895652
# 4    1.637931   6.375000  32.572000   0.000000        17.610526  65.228571
#
#    Student_loan_ded  RE_taxes  PP_taxes  Mortgage_Int_paid  Taxable_inc  \
# 0          1.067021  3.122857  0.676744           8.708955    43.969231
# 1          1.004819  4.105556  0.758537          10.493939    50.748133
# 2          1.004819  4.105556  0.758537          10.493939    50.748133
# 3          1.067021  3.122857  0.676744           8.708955    43.969231
# 4          1.160000  4.311111  0.400000          10.333333    58.208108
#
#    Child_credit  Earned_Inc_credit
# 0      2.125743           2.585463
# 1      2.175097           2.555497
# 2      2.175097           2.555497
# 3      2.125743           2.585463
# 4      1.936000           2.294118

# %%
from google.colab import files
tax_clean_df.to_csv('tax_data.csv', index=False) 
files.download('tax_data.csv')

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

pca = PCA()

# %%
# identify list of numerical features
numers=[]
for col in tax_clean_df.columns:
    if tax_clean_df[col].dtype==('float64') or df[col].dtype==('int64'):
        numers.append(col)

# %%
# scale numeric data for PCA
scaler=StandardScaler()
scaler.fit(tax_clean_df[numers])
scaled_df=scaler.transform(tax_clean_df[numers])

# %%
pca.fit(scaled_df)
# Out:
# PCA()

# %%
# examine the share of variance attributed to the principal components
list(pca.explained_variance_ratio_)
# Out:
# [0.34741627129479863,
#  0.15807554625090656,
#  0.08690473658749366,
#  0.07160182369382499,
#  0.04663059903889842,
#  0.03505249017687583,
#  0.03272802925464937,
#  0.028354052524671946,
#  0.023955425104261373,
#  0.023302974187660898,
#  0.02128047964809961,
#  0.016398037685796805,
#  0.01504052347093225,
#  0.013104785959707717,
#  0.01223184884114492,
#  0.010903402777463286,
#  0.010369745963198443,
#  0.009751944358541183,
#  0.009119288702584617,
#  0.006422750063457419,
#  0.0058777256000177355,
#  0.004848684199808689,
#  0.0035042993807372427,
#  0.002826982748907458,
#  0.0019310175184316344,
#  0.0013674897412249555,
#  0.0006452884110462841,
#  0.00021921464601460273,
#  9.113353335631962e-05,
#  4.3371517591802455e-05,
#  3.711789511775844e-08]

# %%
pca.components_.T.shape
# Out:
# (31, 31)

# %%
tax_clean_df[numers].columns
# Out:
# Index(['latitude', 'longitude', 'baths_half', 'price', 'zip', 'beds',
#        'baths_full', 'year_built', 'square_footage', 'PCT_CHG',
#        'Individuals_taxed', 'Elderly_taxed', 'Total_AGI', 'Number_of_returns',
#        'Total_income', 'Income_per_return', 'Int_Number of returns',
#        'Int_Amount', 'Int_earned', 'Cap_gain', 'Pension', 'UE_claims',
#        'Social_security', 'SB_income', 'Student_loan_ded', 'RE_taxes',
#        'PP_taxes', 'Mortgage_Int_paid', 'Taxable_inc', 'Child_credit',
#        'Earned_Inc_credit'],
#       dtype='object')

# %%
# examine the loading vectors to assess correlations between components and features
loadings = pd.DataFrame(
    pca.components_.T, columns=['PC1', 'PC2', 'PC3', 'PC4','PC5','PC6','PC7','PC8','PC9','PC10',
                                'PC11', 'PC12', 'PC13', 'PC14','PC15','PC16','PC17','PC18','PC19','PC20',
                                'PC21', 'PC22', 'PC23', 'PC24','PC25','PC26','PC27','PC28','PC29','PC30',
                               'PC31'], index=tax_clean_df[numers].columns)
loadings
# Out:
#                             PC1       PC2       PC3       PC4       PC5  \
# latitude               0.054844 -0.099265 -0.280017  0.482999 -0.090348
# longitude             -0.036379  0.186771  0.218713 -0.395026  0.181956
# baths_half             0.018621 -0.023101  0.119493  0.020963  0.103895
# price                  0.085120  0.063355  0.271469  0.252789 -0.141484
# zip                   -0.062137  0.224844  0.167666 -0.296035  0.194408
# beds                  -0.004271 -0.052375  0.437682  0.175860 -0.173623
# baths_full            -0.004058 -0.009966  0.435343  0.233497 -0.171830
# year_built            -0.008713 -0.005740  0.252335  0.157012  0.415069
# square_footage         0.006622 -0.019120  0.479569  0.193818 -0.092577
# PCT_CHG               -0.094836 -0.214496 -0.070838  0.222171  0.039163
# Individuals_taxed      0.149991 -0.370843  0.040285 -0.068332  0.072629
# Elderly_taxed          0.190829 -0.308412  0.031013 -0.035853  0.076859
# Total_AGI              0.258975 -0.214394 -0.001959 -0.043402  0.050787
# Number_of_returns      0.139500 -0.377388  0.024907 -0.087848  0.019974
# Total_income           0.259105 -0.214084 -0.002233 -0.043590  0.050060
# Income_per_return      0.278726  0.127162 -0.014823  0.013063  0.028231
# Int_Number of returns  0.258838 -0.206282  0.004958 -0.024931  0.106041
# Int_Amount             0.282122 -0.035299 -0.022634 -0.028496 -0.045131
# Int_earned             0.206914  0.214174 -0.030629 -0.004550 -0.204439
# Cap_gain               0.215864  0.178751  0.017790 -0.097364 -0.218343
# Pension                0.170604  0.187338  0.044396  0.022093  0.002079
# UE_claims              0.125332 -0.202513  0.102989 -0.245477 -0.102342
# Social_security        0.259254  0.148434  0.018863  0.056898  0.063609
# SB_income              0.206645  0.142221  0.033702 -0.051549 -0.124817
# Student_loan_ded       0.041462 -0.114064 -0.019169 -0.186902 -0.464156
#
#                            PC26      PC27      PC28      PC29      PC30  \
# latitude               0.006377 -0.009369 -0.002493 -0.014365  0.000223
# longitude             -0.013985 -0.002239  0.001320 -0.012902 -0.001185
# baths_half             0.004637  0.006940 -0.000482 -0.000175  0.001492
# price                  0.010905  0.009518  0.002240  0.001609  0.001208
# zip                   -0.000663  0.007982 -0.002586 -0.002869 -0.004549
# beds                  -0.006000 -0.005251 -0.000985 -0.000756  0.000924
# baths_full             0.010472  0.002446 -0.001492 -0.001210  0.000419
# year_built            -0.007162 -0.023284 -0.001663 -0.005133 -0.004571
# square_footage        -0.015020 -0.010783 -0.000374 -0.003604 -0.002085
# PCT_CHG               -0.009026 -0.012782 -0.007949 -0.016896 -0.003407
# Individuals_taxed      0.216292  0.086063 -0.403078  0.645707 -0.011412
# Elderly_taxed         -0.768462  0.126718  0.259307  0.102297 -0.026672
# Total_AGI              0.250065 -0.159059  0.450716  0.111215  0.007133
# Number_of_returns      0.194685  0.172386 -0.008915 -0.696092 -0.017367
# Total_income           0.249339 -0.155974  0.445155  0.097598  0.002376
# Income_per_return     -0.216328  0.000522 -0.063114 -0.003465  0.687282
# Int_Number of returns -0.082770 -0.569148 -0.527266 -0.226986  0.099294
# Int_Amount             0.053743  0.646962 -0.241682 -0.060660 -0.045373
# Int_earned             0.000631 -0.306111  0.079050  0.003613  0.024396
# Cap_gain               0.036967  0.019943 -0.023268  0.002224  0.000570
# Pension                0.218351 -0.002527  0.004711  0.001030 -0.000223
# UE_claims              0.013085  0.002870 -0.001751  0.016275  0.002961
# Social_security        0.179837  0.105656  0.015259 -0.005983  0.000515
# SB_income              0.006305 -0.003820 -0.015216  0.011699 -0.003205
# Student_loan_ded       0.014948  0.009702 -0.006352  0.010006 -0.001075
# RE_taxes              -0.120314  0.036765  0.056523  0.020560  0.004014
# PP_taxes               0.002051 -0.045658  0.002745 -0.014386 -0.004393
# Mortgage_Int_paid     -0.012772  0.101459 -0.021408  0.002119  0.024567
# Taxable_inc           -0.201917 -0.142567 -0.115871 -0.024530 -0.715486
# Child_credit           0.008151  0.116804  0.063252 -0.071832 -0.031049
# Earned_Inc_credit     -0.073227  0.021559  0.000434 -0.057296  0.017964
#
#                            PC31
# latitude              -0.000223
# longitude             -0.000047
# baths_half             0.000004
# price                  0.000032
# zip                   -0.000061
# beds                  -0.000002
# baths_full             0.000015
# year_built             0.000074
# square_footage         0.000028
# PCT_CHG                0.000027
# Individuals_taxed      0.004694
# Elderly_taxed          0.001454
# Total_AGI             -0.703766
# Number_of_returns     -0.007034
# Total_income           0.710357
# Income_per_return      0.001793
# Int_Number of returns -0.002603
# Int_Amount            -0.003306
# Int_earned             0.000857
# Cap_gain               0.000252
# Pension                0.000454
# UE_claims             -0.000014
# Social_security       -0.000587
# SB_income             -0.000124
# Student_loan_ded       0.000015
# RE_taxes              -0.000551
# PP_taxes               0.000015
# Mortgage_Int_paid      0.000409
# Taxable_inc           -0.003015
# Child_credit           0.000107
# Earned_Inc_credit     -0.000236
