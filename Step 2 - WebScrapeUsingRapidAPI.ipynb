# %% [markdown]
# ## Using RapidAPI to scrape Zillow data
#
# ### Key attributes needs for analysis are Zestimate, price per square ft and rentZestimate
#
# We are using Georgia (GA) Listing data to get all the addresses of properties which are on interest. We then use following sources to augment that data:
# * Zillow
# * IRS (Tax data)
# * FHFA (HPI data)
#
# The data is then further transformed by feature extraction or feature engineeting work, for example:
# * Schools (from Zillow)
# * Lot Size (from Zillow and GA Listings)

# %%
#!pip install googlesearch-python
# Out:
# Requirement already satisfied: googlesearch-python in /Users/nimitsharma/opt/anaconda3/lib/python3.9/site-packages (1.1.0)
# Requirement already satisfied: beautifulsoup4==4.9.3 in /Users/nimitsharma/opt/anaconda3/lib/python3.9/site-packages (from googlesearch-python) (4.9.3)
# Requirement already satisfied: requests==2.25.1 in /Users/nimitsharma/opt/anaconda3/lib/python3.9/site-packages (from googlesearch-python) (2.25.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/nimitsharma/opt/anaconda3/lib/python3.9/site-packages (from beautifulsoup4==4.9.3->googlesearch-python) (2.3.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/nimitsharma/opt/anaconda3/lib/python3.9/site-packages (from requests==2.25.1->googlesearch-python) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/nimitsharma/opt/anaconda3/lib/python3.9/site-packages (from requests==2.25.1->googlesearch-python) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/nimitsharma/opt/anaconda3/lib/python3.9/site-packages (from requests==2.25.1->googlesearch-python) (1.26.9)
# Requirement already satisfied: idna<3,>=2.5 in /Users/nimitsharma/opt/anaconda3/lib/python3.9/site-packages (from requests==2.25.1->googlesearch-python) (2.10)

# %%
#pip install google
# Out:
# Collecting google
#   Downloading google-3.0.0-py2.py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 472 kB/s eta 0:00:01
# Requirement already satisfied: beautifulsoup4 in /Users/nimitsharma/opt/anaconda3/lib/python3.9/site-packages (from google) (4.9.3)
# Requirement already satisfied: soupsieve>1.2 in /Users/nimitsharma/opt/anaconda3/lib/python3.9/site-packages (from beautifulsoup4->google) (2.3.1)
# Installing collected packages: google
# Successfully installed google-3.0.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Importing Key Libraries

# %%
from googlesearch import search # get zpid
import pandas as pd
import numpy as np
import requests
import json
import time
import io
import plotly.express as px

# show all columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### <font color=blue> This function use google search and find zpid (primary key for zillow)
# #### RapidAPI requires zpid

# %%
def get_zpid(street=None, city=None, state=None, zip_code=None, full_address=None):
  # get search query string
  if full_address == None:
    try:
      query = '{0}, {1}, {2} {3} zillow home details'.format(street, city, state, str(zip_code))
    except:
      return 'Please enter a query string or address details'
  else:
    query = full_address + ' zillow home details'

  # get google search results
  search_results = search(query, tld='com', lang='en', num=3, start=0, stop=1, pause=0)
  search_results_list = [u for u in search_results]
  url = search_results_list[0] # extract first returned result
  
  # return zpid
  try:
    return [x for x in url.split('/') if 'zpid' in x][0].split('_')[0]
  except:
    return None

# %% [markdown]
# ### <font color=blue> Register and test the Rapid API key

# %%
rapid_api_key = "please_use_a_valid_key"

# %%
def get_property_detail(rapid_api_key, zpid):
  # get property details from API
  url = "https://zillow-com1.p.rapidapi.com/property"

  querystring = {"zpid":zpid} # zpid

  headers = {
    "X-RapidAPI-Host": "zillow-com1.p.rapidapi.com",
    "X-RapidAPI-Key": rapid_api_key # your key here
  }

  # request data
  return requests.request("GET", url, headers=headers, params=querystring)

# %% [markdown]
# Testing the API

# %%
import requests

url = "https://zillow-com1.p.rapidapi.com/property"

querystring = {"zpid":"2080998890"}

headers = {
    "X-RapidAPI-Key": "rapid_api_key",
    "X-RapidAPI-Host": "zillow-com1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"listingProvider":{"enhancedVideoURL":null,"showNoContactInfoMessage":false,"postingGroupName":null,"isZRMSourceText":null,"showLogos":null,"disclaimerText":null,"sourceText":null,"title":"Listing Provided by","logos":{},"postingWebsiteURL":null,"agentLicenseNumber":null,"postingWebsiteLinkText":"See listing website","enhancedDescriptionText":null,"agentName":null},"buildingPermits":null,"propertyTaxRate":1.01,"contact_recipients":[{"agent_reason":1,"zpro":null,"recent_sales":0,"review_count":56,"display_name":"Jim Pullin","zuid":"X1-ZU11t0lr5j8rqx5_34dhh","rating_average":5,"badge_type":"Premier Agent","phone":{"prefix":"207","areacode":"206","number":"8763"},"image_url":"https:\/\/photos.zillowstatic.com\/h_n\/ISfkgeu1boe63o1000000000.jpg"}],"solarPotential":null,"longitude":-122.34212,"countyFIPS":null,"cityId":16037,"timeOnZillow":"611 days","url":"\/homedetails\/757-Hayes-St-Seattle-WA-98109\/2080998890_zpid\/","zestimate":null,"imgSrc":"https:\/\/photos.zillowstatic.com\/fp\/306c91504435f821b222f2e5acb36d0d-p_d.jpg","zpid":2080998890,"zipcode":"98109","livingAreaValue":2236,"zestimateLowPercent":null,"isListedByOwner":false,"propertyTypeDimension":"Townhouse","resoFacts":{"hasAttachedProperty":false,"frontageType":null,"poolFeatures":null,"flooring":["Tile","Hardwood"],"foundationDetails":{},"accessibilityFeatures":null,"hasGarage":false,"hasPetsAllowed":null,"bodyType":null,"topography":null,"landLeaseExpirationDate":null,"hasAdditionalParcels":false,"waterViewYN":null,"atAGlanceFacts":[{"factLabel":"Type","factValue":"Townhouse"},{"factLabel":"Year Built","factValue":"2020"},{"factLabel":"Heating","factValue":"Heat pump"},{"factLabel":"Cooling","factValue":null},{"factLabel":"Parking","factValue":"1 Parking space"},{"factLabel":"HOA","factValue":"$49 monthly"},{"factLabel":"Lot","factValue":"801 sqft"},{"factLabel":"Offer Review Date","factValue":null}],"offerReviewDate":null,"aboveGradeFinishedArea":null,"view":["City"],"buyerAgencyCompensationType":null,"rooms":[{"level":null,"dimensions":null,"features":null,"roomFeatures":null,"roomArea":null,"roomAreaSource":null,"roomLength":null,"width":null,"roomDescription":null,"roomWidth":null,"roomLevel":null,"roomLengthWidthUnits":null,"roomLengthWidthSource":null,"roomDimensions":null,"roomAreaUnits":null,"roomType":"WalkInCloset","length":null,"description":null,"area":null},{"level":null,"dimensions":null,"features":null,"roomFeatures":null,"roomArea":null,"roomAreaSource":null,"roomLength":null,"width":null,"roomDescription":null,"roomWidth":null,"roomLevel":null,"roomLengthWidthUnits":null,"roomLengthWidthSource":null,"roomDimensions":null,"roomAreaUnits":null,"roomType":"DiningRoom","length":null,"description":null,"area":null}],"carportSpaces":null,"cityRegion":"Seattle","mainLevelBathrooms":null,"hasPrivatePool":null,"associationFeeIncludes":null,"waterSource":["Public"],"exteriorFeatures":["Wood","Cement \/ Concrete"],"coveredSpaces":null,"inclusions":null,"hasFireplace":null,"zoningDescription":null,"garageSpaces":null,"sewer":["Sewer Connected"],"elevationUnits":null,"exclusions":null,"mainLevelBedrooms":null,"numberOfUnitsVacant":null,"hasWaterfrontView":null,"listAOR":null,"lotSize":"801 sqft","entryLevel":null,"irrigationWaterRightsAcres":null,"greenWaterConservation":null,"stories":null,"livingArea":"2,236 sqft","numberOfUnitsInCommunity":null,"listingTerms":null,"otherStructures":null,"associationFee":null,"marketingType":null,"greenIndoorAirQuality":null,"greenSustainability":null,"hasHomeWarranty":false,"associationPhone":null,"greenBuildingVerificationType":null,"elementarySchool":"John Hay Elementary","bedrooms":3,"architecturalStyle":null,"listingId":null,"structureType":"Modern","interiorFeatures":null,"horseAmenities":null,"electric":null,"developmentStatus":null,"lotFeatures":null,"roofType":null,"waterSources":null,"constructionMaterials":{},"fireplaceFeatures":null,"doorFeatures":null,"appliances":["Dishwasher","Garbage disposal","Microwave","Ran ...

# %%
# property address
property_address = "84 Whippoorwill Circle, Kingsland, GA 31548" # https://www.zillow.com/homedetails/11622-Pure-Pebble-Dr-Riverview-FL-33569/66718658_zpid/

# search query
query = property_address + ' zillow home details'
print('Search this phrase in Google Search:', query)
# Out:
# Search this phrase in Google Search: 84 Whippoorwill Circle, Kingsland, GA 31548 zillow home details

# %%
# google search results
search_results = search(query, tld='com', lang='en', num=3, start=0, stop=3, pause=0)
search_results_list = [u for u in search_results] # get all results
search_results_list
# Out:
# ['https://www.zillow.com/homedetails/84-Whippoorwill-Cir-Kingsland-GA-31548/76375189_zpid/',
#  'https://www.compass.com/listing/84-whippoorwill-circle-kingsland-ga-31548/1020322606183510697/',
#  'https://www.coldwellbankerhomes.com/ga/kingsland/84-whippoorwill-circle/pid_46488818/']

# %%
# get the first search result
url = search_results_list[0] # extract first returned result
url
# Out:
# 'https://www.zillow.com/homedetails/84-Whippoorwill-Cir-Kingsland-GA-31548/76375189_zpid/'

# %%
# extract the zpid
zpid = [x for x in url.split('/') if 'zpid' in x][0].split('_')[0]
print('Zpid of the property is:', zpid )
# Out:
# Zpid of the property is: 76375189

# %%
# get property details from API
url = "https://zillow-com1.p.rapidapi.com/property"

querystring = {"zpid":zpid} # zpid

headers = {
    "X-RapidAPI-Host": "zillow-com1.p.rapidapi.com",
    "X-RapidAPI-Key": rapid_api_key # your key here
}

# request data
response = requests.request("GET", url, headers=headers, params=querystring)
# show success
response.status_code # 200 is success!
# Out:
# 200

# %%
response.json()
# Out:
# {'listingProvider': None,
#  'buildingPermits': None,
#  'propertyTaxRate': 0.98,
#  'contact_recipients': [{'agent_reason': 1,
#    'zpro': None,
#    'recent_sales': 1,
#    'review_count': 66,
#    'display_name': 'Hannah Melton',
#    'zuid': 'X1-ZUzlemig891155_8qndh',
#    'rating_average': 5,
#    'badge_type': 'Premier Agent',
#    'phone': {'prefix': '380', 'areacode': '912', 'number': '3440'},
#    'image_url': 'https://photos.zillowstatic.com/h_n/ISfo72urg9xp1t1000000000.jpg'}],
#  'solarPotential': {'sunScore': 64.35,
#   'solarFactor': 3.04,
#   'buildFactor': 52,
#   'climateFactor': 6.67,
#   'electricityFactor': 2.64},
#  'longitude': -81.66023,
#  'countyFIPS': '13039',
#  'cityId': 52779,
#  'timeOnZillow': '146 days',
#  'url': '/homedetails/84-Whippoorwill-Cir-Kingsland-GA-31548/76375189_zpid/',
#  'zestimate': 235700,
#  'imgSrc': 'https://photos.zillowstatic.com/fp/9d94004ba25c8463f8d134d7a4e7f3fc-p_d.jpg',
#  'zpid': 76375189,
#  'zipcode': '31548',
#  'livingAreaValue': 1618,
#  'zestimateLowPercent': None,
#  'isListedByOwner': False,
#  'propertyTypeDimension': 'Single Family',
#  'resoFacts': {'hasAttachedProperty': False,
#   'frontageType': None,
#   'poolFeatures': None,
#   'flooring': ['Carpet', 'Tile'],
#   'foundationDetails': ['Slab'],
#   'accessibilityFeatures': None,
#   'hasGarage': False,
#   'hasPetsAllowed': None,
#   'bodyType': None,
#   'topography': None,
#   'landLeaseExpirationDate': None,
#   'hasAdditionalParcels': False,
#   'waterViewYN': None,
#   'atAGlanceFacts': [{'factLabel': 'Type',
#     'factValue': 'Single Family Residence'},
#    {'factLabel': 'Year Built', 'factValue': '1986'},
#    {'factLabel': 'Heating', 'factValue': 'Heat Pump'},
#    {'factLabel': 'Cooling', 'factValue': 'Central Air'},
#    {'factLabel': 'Parking', 'factValue': 'Open Parking'},
#    {'factLabel': 'Lot', 'factValue': None},
#    {'factLabel': 'Offer Review Date', 'factValue': None}],
#   'offerReviewDate': None,
#   'aboveGradeFinishedArea': '1,618',
#   'view': {},
#   'buyerAgencyCompensationType': None,
#   'rooms': {},
#   'carportSpaces': None,
#   'cityRegion': 'Kingsland',
#   'mainLevelBathrooms': 2,
#   'hasPrivatePool': None,
#   'associationFeeIncludes': ['None'],
#   'waterSource': ['Public'],
#   'exteriorFeatures': {},
#   'coveredSpaces': None,
#   'inclusions': None,
#   'hasFireplace': False,
#   'zoningDescription': None,
#   'garageSpaces': None,
#   'sewer': ['Public Sewer'],
#   'elevationUnits': None,
#   'exclusions': None,
#   'mainLevelBedrooms': 3,
#   'numberOfUnitsVacant': None,
#   'hasWaterfrontView': None,
#   'listAOR': None,
#   'lotSize': None,
#   'entryLevel': None,
#   'irrigationWaterRightsAcres': None,
#   'greenWaterConservation': None,
#   'stories': None,
#   'livingArea': '1,618 sqft',
#   'numberOfUnitsInCommunity': None,
#   'listingTerms': None,
#   'otherStructures': None,
#   'associationFee': None,
#   'marketingType': None,
#   'greenIndoorAirQuality': None,
#   'greenSustainability': None,
#   'hasHomeWarranty': False,
#   'associationPhone': None,
#   'greenBuildingVerificationType': None,
#   'elementarySchool': 'David L Rainer',
#   'bedrooms': 3,
#   'architecturalStyle': 'Ranch',
#   'listingId': None,
#   'structureType': 'House',
#   'interiorFeatures': ['Master Downstairs'],
#   'horseAmenities': None,
#   'electric': None,
#   'developmentStatus': None,
#   'lotFeatures': ['Level'],
#   'roofType': 'Composition',
#   'waterSources': None,
#   'constructionMaterials': ['Tabby'],
#   'fireplaceFeatures': None,
#   'doorFeatures': None,
#   'appliances': ['Electric Water Heater'],
#   'daysOnZillow': 146,
#   'bathroomsPartial': None,
#   'bathroomsHalf': 0,
#   'depositsAndFees': None,
#   'canRaiseHorses': False,
#   'buildingName': None,
#   'hasAssociation': False,
#   'petsMaxWeight': None,
#   'commonWalls': None,
#   'totalActualRent': None,
#   'additionalParcelsDescription': None,
#   'associationName': None,
#   'allowedPets': None,
#   'communityFeatures': ['None'],
#   'tenantPays': None,
#   'middleOrJuniorSchool': 'Camden',
#   'lotSizeDimensions': None,
#   'roadSurfaceType': None,
#   'hasOpenParking': True,
#   'yearBuilt': 1986,
#   'livingAreaRangeUnits': None,
#   'irrigationWaterRightsYN': None,
#   'bathroomsFull': 2,
#   'horseYN': None,
#   'incomeIncludes': None,
#   'highSchool': 'Camden County',
#   'leaseTerm': None,
#   'elevation': None,
#   'cropsIncludedYN': None,
#   'attic': None,
#   'subdivisionName': 'Deer Run',
#   'windowFeatures': None,
#   'ownership': None,
#   'woodedArea': None,
#   'middleOrJuniorSchoolDistrict': None,
#   'associationPhone2': None,
#   'buyerAgencyCompensation': None,
#   'heating': ['Heat Pump'],
#   'frontageLength': None,
#   'virtualTourURLUnbranded': None,
#   'associationAmenities': None,
#   'propertySubType': ['Single Family Residence'],
#   'hasCooling': True,
#   'belowGradeFinishedArea': '0',
#   'hasElectricOnProperty': True,
#   'foundationArea': None,
#   'zoning': None,
#   'hoaFee': None,
#   'livingAreaRange': None,
#   'basementYN': False,
#   'availabilityDate': None,
#   'waterBodyName': None,
#   'waterfrontFeatures': None,
#   'specialListingConditions': None,
#   'buildingAreaSource': None,
#   'taxAnnualAmount': 1714,
#   'parking': 0,
#   'hasView': False,
#   'virtualTour': None,
#   'securityFeatures': None,
#   'cooling': ['Central Air'],
#   'entryLocation': None,
#   'otherFacts': {},
#   'levels': 'One',
#   'ownershipType': None,
#   'basement': 'None',
#   'onMarketDate': 1649376000000,
#   'waterView': None,
#   'laundryFeatures': ['In Garage', 'Other'],
#   'hasAttachedGarage': False,
#   'fencing': None,
#   'spaFeatures': None,
#   'bathrooms': 2,
#   'homeType': 'SingleFamily',
#   'isSeniorCommunity': None,
#   'municipality': None,
#   'bathroomsThreeQuarter': None,
#   'hasSpa': False,
#   'otherParking': None,
#   'associationFee2': None,
#   'parcelNumber': '108C 003',
#   'hasHeating': True,
#   'associationName2': None,
#   'hasRentControl': None,
#   'elementarySchoolDistrict': None,
#   'otherEquipment': None,
#   'parkingFeatures': ['Parking Pad'],
#   'buildingArea': '1,618',
#   'furnished': False,
#   'vegetation': None,
#   'patioAndPorchFeatures': None,
#   'buildingFeatures': None,
#   'builderName': None,
#   'highSchoolDistrict': None,
#   'propertyCondition': 'Resale',
#   'storiesTotal': None,
#   'yearBuiltEffective': None,
#   'fireplaces': 0,
#   'bathroomsOneQuarter': None,
#   'builderModel': None,
#   'gas': None,
#   'utilities': ['Electricity Available',
#    'Phone Available',
#    'Sewer Available',
#    'Water Available'],
#   'greenEnergyEfficient': None,
#   'landLeaseAmount': None,
#   'isNewConstruction': False,
#   'hasLandLease': False,
#   'pricePerSquareFoot': 136,
#   'hasCarport': False,
#   'openParkingSpaces': None},
#  'streetAddress': '84 Whippoorwill Cir',
#  'county': None,
#  'taxHistory': [{'time': 1633211731420,
#    'valueIncreaseRate': 0.058007967,
#    'taxIncreaseRate': 0.028743092,
#    'taxPaid': 1714.03,
#    'value': 53112},
#   {'time': 1601675731420,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0.08428891,
#    'taxPaid': 1666.14,
#    'value': 50200},
#   {'time': 1570053331420,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0,
#    'taxPaid': 1536.62,
#    'value': 50200},
#   {'time': 1538517331420,
#    'valueIncreaseRate': 0.08789875,
#    'taxIncreaseRate': 0.018296754,
#    'taxPaid': 1536.62,
#    'value': 50200},
#   {'time': 1506981331420,
#    'valueIncreaseRate': 0.061611373,
#    'taxIncreaseRate': 0.065354034,
#    'taxPaid': 1509.01,
#    'value': 46144},
#   {'time': 1475445331420,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0,
#    'taxPaid': 1416.44,
#    'value': 43466},
#   {'time': 1443822931420,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0.10353308,
#    'taxPaid': 1416.44,
#    'value': 43466},
#   {'time': 1412286931420,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0,
#    'taxPaid': 1283.55,
#    'value': 43466},
#   {'time': 1380750931420,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0,
#    'taxPaid': 1283.55,
#    'value': 43466},
#   {'time': 1349214931420,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0,
#    'taxPaid': None,
#    'value': None},
#   {'time': 1317592531420,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0,
#    'taxPaid': None,
#    'value': None},
#   {'time': 1286056531420,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0,
#    'taxPaid': None,
#    'value': None},
#   {'time': 1254520531420,
#    'valueIncreaseRate': -0.12626201,
#    'taxIncreaseRate': 0,
#    'taxPaid': None,
#    'value': 57118},
#   {'time': 1222984531420,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0,
#    'taxPaid': None,
#    'value': 65372},
#   {'time': 1191362131420,
#    'valueIncreaseRate': 0.42630854,
#    'taxIncreaseRate': 0,
#    'taxPaid': None,
#    'value': 65372},
#   {'time': 1159826131420,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0,
#    'taxPaid': None,
#    'value': 45833},
#   {'time': 1128290131420,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0,
#    'taxPaid': None,
#    'value': 45833},
#   {'time': 1096754131420,
#    'valueIncreaseRate': 0.4225457,
#    'taxIncreaseRate': 0,
#    'taxPaid': None,
#    'value': 45833},
#   {'time': 1065131731420,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0,
#    'taxPaid': None,
#    'value': 32219},
#   {'time': 1033595731420,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0,
#    'taxPaid': None,
#    'value': 32219},
#   {'time': 1002059731420,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0,
#    'taxPaid': None,
#    'value': 32219}],
#  'stateId': 16,
#  'countyId': 908,
#  'timeZone': 'America/New_York',
#  'homeType': 'SINGLE_FAMILY',
#  'livingAreaUnits': 'sqft',
#  'comingSoonOnMarketDate': None,
#  'livingArea': 1618,
#  'bathrooms': 2,
#  'annualHomeownersInsurance': 924,
#  'state': 'GA',
#  'rentZestimate': 1649,
#  'building': None,
#  'brokerId': None,
#  'yearBuilt': 1986,
#  'brokerageName': 'BHHS Hodnett Cooper RealEstate',
#  'dateSold': '2022-05-09',
#  'price': 220000,
#  'pageViewCount': 0,
#  'description': 'Property being sold as is. Seller has never occupied the home and has no knowledge. A sellers disclosure shall not be provided. Lots of potential with little renovation.',
#  'mortgageRates': {'arm5Rate': None,
#   'fifteenYearFixedRate': 6.008,
#   'thirtyYearFixedRate': 6.625},
#  'homeStatus': 'RECENTLY_SOLD',
#  'homeFacts': None,
#  'latitude': 30.762964,
#  'datePosted': '2022-05-12',
#  'bedrooms': 3,
#  'nearbyHomes': [{'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/31dcbfc826488f0f18a8c8f4c704ea9c-p_c.jpg'}],
#    'zpid': 76375193,
#    'longitude': -81.660736,
#    'address': {'city': 'Kingsland',
#     'state': 'GA',
#     'streetAddress': '106 Whippoorwill Cir',
#     'zipcode': '31548'},
#    'price': 187000,
#    'homeType': 'SINGLE_FAMILY',
#    'homeStatus': 'SOLD',
#    'currency': 'USD',
#    'latitude': 30.76284},
#   {'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/d753545b27c338f8475b609434c2f630-p_c.jpg'}],
#    'zpid': 91032680,
#    'longitude': -81.659706,
#    'address': {'city': 'Kingsland',
#     'state': 'GA',
#     'streetAddress': '66 Whippoorwill Cir',
#     'zipcode': '31548'},
#    'price': 217500,
#    'homeType': 'SINGLE_FAMILY',
#    'homeStatus': 'SOLD',
#    'currency': 'USD',
#    'latitude': 30.763033},
#   {'miniCardPhotos': [{'url': 'https://maps.googleapis.com/maps/api/streetview?location=47+Whippoorwill+Cir%2C+Kingsland%2C+GA+31548&size=316x234&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&source=outdoor&&signature=TsL-lj8I_GKat6lb74klXtODSUU='}],
#    'zpid': 91032676,
#    'longitude': -81.660034,
#    'address': {'city': 'Kingsland',
#     'state': 'GA',
#     'streetAddress': '47 Whippoorwill Cir',
#     'zipcode': '31548'},
#    'price': 243800,
#    'homeType': 'SINGLE_FAMILY',
#    'homeStatus': 'OTHER',
#    'currency': 'USD',
#    'latitude': 30.762348},
#   {'miniCardPhotos': [{'url': 'https://maps.googleapis.com/maps/api/streetview?location=97+Whippoorwill+Cir%2C+Kingsland%2C+GA+31548&size=316x234&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&source=outdoor&&signature=meXF9aW3o75Cxotk3nkPU6KLUCc='}],
#    'zpid': 76375151,
#    'longitude': -81.66048,
#    'address': {'city': 'Kingsland',
#     'state': 'GA',
#     'streetAddress': '97 Whippoorwill Cir',
#     'zipcode': '31548'},
#    'price': 262500,
#    'homeType': 'SINGLE_FAMILY',
#    'homeStatus': 'OTHER',
#    'currency': 'USD',
#    'latitude': 30.762241},
#   {'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/9a678e6820c3cd84887f3696cd833231-p_c.jpg'}],
#    'zpid': 76375121,
#    'longitude': -81.65943,
#    'address': {'city': 'Kingsland',
#     'state': 'GA',
#     'streetAddress': '56 Whippoorwill Cir',
#     'zipcode': '31548'},
#    'price': 277000,
#    'homeType': 'SINGLE_FAMILY',
#    'homeStatus': 'OTHER',
#    'currency': 'USD',
#    'latitude': 30.762651},
#   {'miniCardPhotos': [{'url': 'https://maps.googleapis.com/maps/api/streetview?location=2226+Scrubby+Bluff+Rd%2C+Kingsland%2C+GA+31548&size=316x234&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&source=outdoor&&signature=zs1Sn_Yti1E9fHKNq6p9YBkikTs='}],
#    'zpid': 223781960,
#    'longitude': -81.66047,
#    'address': {'city': 'Kingsland',
#     'state': 'GA',
#     'streetAddress': '2226 Scrubby Bluff Rd',
#     'zipcode': '31548'},
#    'price': 60600,
#    'homeType': 'SINGLE_FAMILY',
#    'homeStatus': 'OTHER',
#    'currency': 'USD',
#    'latitude': 30.76377},
#   {'miniCardPhotos': [{'url': 'https://maps.googleapis.com/maps/api/streetview?location=2226+Scrubby+Bluff+Rd%2C+Kingsland%2C+GA+31548&size=316x234&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&source=outdoor&&signature=zs1Sn_Yti1E9fHKNq6p9YBkikTs='}],
#    'zpid': 223781961,
#    'longitude': -81.66047,
#    'address': {'city': 'Kingsland',
#     'state': 'GA',
#     'streetAddress': '2226 Scrubby Bluff Rd',
#     'zipcode': '31548'},
#    'price': 4553,
#    'homeType': 'MANUFACTURED',
#    'homeStatus': 'OTHER',
#    'currency': 'USD',
#    'latitude': 30.76377},
#   {'miniCardPhotos': [{'url': 'https://maps.googleapis.com/maps/api/streetview?location=2226+Scrubby+Bluff+Rd%2C+Kingsland%2C+GA+31548&size=316x234&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&source=outdoor&&signature=zs1Sn_Yti1E9fHKNq6p9YBkikTs='}],
#    'zpid': 299551398,
#    'longitude': -81.66047,
#    'address': {'city': 'Kingsland',
#     'state': 'GA',
#     'streetAddress': '2226 Scrubby Bluff Rd',
#     'zipcode': '31548'},
#    'price': 2277,
#    'homeType': 'SINGLE_FAMILY',
#    'homeStatus': 'OTHER',
#    'currency': 'USD',
#    'latitude': 30.76377}],
#  'monthlyHoaFee': None,
#  'priceHistory': [{'priceChangeRate': 0.1,
#    'date': '2022-05-09',
#    'source': 'GAMLS',
#    'postingIsRental': False,
#    'time': 1652054400000,
#    'sellerAgent': {'name': 'Stephana Dixon',
#     'photo': {'url': 'https://photos.zillowstatic.com/h_e/ISfwp1ca5si3kn0000000000.jpg'},
#     'profileUrl': '/profile/sgdixon/'},
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'GAMLS',
#     'infoString3': 'https://photos.zillowstatic.com/fp/0cb94cd8ded4a691f746b2119208ab23-zillow_web_logo_inf_11.jpg',
#     'infoString1': '10036340'},
#    'pricePerSquareFoot': 136,
#    'buyerAgent': {'name': 'Alissa Williams',
#     'photo': {'url': 'https://photos.zillowstatic.com/h_e/ISzjdfn1nujjef1000000000.jpg'},
#     'profileUrl': '/profile/youragentalissa1/'},
#    'event': 'Sold',
#    'price': 220000},
#   {'priceChangeRate': 0,
#    'date': '2022-04-10',
#    'source': 'GAMLS',
#    'postingIsRental': False,
#    'time': 1649548800000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'GAMLS',
#     'infoString3': 'https://photos.zillowstatic.com/fp/0cb94cd8ded4a691f746b2119208ab23-zillow_web_logo_inf_11.jpg',
#     'infoString1': '10036340'},
#    'pricePerSquareFoot': 124,
#    'buyerAgent': None,
#    'event': 'Pending sale',
#    'price': 200000},
#   {'priceChangeRate': 2.3333333333333,
#    'date': '2022-04-08',
#    'source': 'GAMLS',
#    'postingIsRental': False,
#    'time': 1649376000000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'GAMLS',
#     'infoString3': 'https://photos.zillowstatic.com/fp/0cb94cd8ded4a691f746b2119208ab23-zillow_web_logo_inf_11.jpg',
#     'infoString1': '10036340'},
#    'pricePerSquareFoot': 124,
#    'buyerAgent': None,
#    'event': 'Listed for sale',
#    'price': 200000},
#   {'priceChangeRate': -0.032258064516129,
#    'date': '2011-08-31',
#    'source': 'Public Record',
#    'postingIsRental': False,
#    'time': 1314748800000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'Public Record',
#     'infoString3': None,
#     'infoString1': None},
#    'pricePerSquareFoot': 37,
#    'buyerAgent': None,
#    'event': 'Sold',
#    'price': 60000},
#   {'priceChangeRate': 0,
#    'date': '2011-08-06',
#    'source': 'ERA Kings Bay Realty',
#    'postingIsRental': False,
#    'time': 1312588800000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'ERA Kings Bay Realty',
#     'infoString3': None,
#     'infoString1': None},
#    'pricePerSquareFoot': 38,
#    'buyerAgent': None,
#    'event': 'Listing removed',
#    'price': 62000},
#   {'priceChangeRate': -0.11931818181818,
#    'date': '2011-07-30',
#    'source': 'ERA Kings Bay Realty',
#    'postingIsRental': False,
#    'time': 1311984000000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'ERA Kings Bay Realty',
#     'infoString3': None,
#     'infoString1': None},
#    'pricePerSquareFoot': 38,
#    'buyerAgent': None,
#    'event': 'Price change',
#    'price': 62000},
#   {'priceChangeRate': 0,
#    'date': '2011-07-27',
#    'source': '--',
#    'postingIsRental': False,
#    'time': 1311724800000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': None,
#     'infoString3': None,
#     'infoString1': None},
#    'pricePerSquareFoot': 44,
#    'buyerAgent': None,
#    'event': 'Listed for sale',
#    'price': 70400},
#   {'priceChangeRate': 0,
#    'date': '2011-06-07',
#    'source': 'ERA Kings Bay Realty',
#    'postingIsRental': False,
#    'time': 1307404800000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'ERA Kings Bay Realty',
#     'infoString3': None,
#     'infoString1': None},
#    'pricePerSquareFoot': 44,
#    'buyerAgent': None,
#    'event': 'Listing removed',
#    'price': 70400},
#   {'priceChangeRate': -0.1188986232791,
#    'date': '2011-05-20',
#    'source': 'ERA Kings Bay Realty',
#    'postingIsRental': False,
#    'time': 1305849600000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'ERA Kings Bay Realty',
#     'infoString3': None,
#     'infoString1': None},
#    'pricePerSquareFoot': 44,
#    'buyerAgent': None,
#    'event': 'Price change',
#    'price': 70400},
#   {'priceChangeRate': -0.082663605051665,
#    'date': '2011-03-04',
#    'source': 'ERA Kings Bay Realty',
#    'postingIsRental': False,
#    'time': 1299196800000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'ERA Kings Bay Realty',
#     'infoString3': None,
#     'infoString1': None},
#    'pricePerSquareFoot': 49,
#    'buyerAgent': None,
#    'event': 'Price change',
#    'price': 79900},
#   {'priceChangeRate': -0.053260869565217,
#    'date': '2011-02-18',
#    'source': 'ERA Kings Bay Realty',
#    'postingIsRental': False,
#    'time': 1297987200000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'ERA Kings Bay Realty',
#     'infoString3': None,
#     'infoString1': None},
#    'pricePerSquareFoot': 54,
#    'buyerAgent': None,
#    'event': 'Price change',
#    'price': 87100},
#   {'priceChangeRate': -0.049586776859504,
#    'date': '2011-01-26',
#    'source': 'ERA Kings Bay Realty',
#    'postingIsRental': False,
#    'time': 1296000000000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'ERA Kings Bay Realty',
#     'infoString3': None,
#     'infoString1': None},
#    'pricePerSquareFoot': 57,
#    'buyerAgent': None,
#    'event': 'Price change',
#    'price': 92000},
#   {'priceChangeRate': -0.03968253968254,
#    'date': '2010-12-31',
#    'source': 'ERA Kings Bay Realty',
#    'postingIsRental': False,
#    'time': 1293753600000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'ERA Kings Bay Realty',
#     'infoString3': None,
#     'infoString1': None},
#    'pricePerSquareFoot': 60,
#    'buyerAgent': None,
#    'event': 'Price change',
#    'price': 96800},
#   {'priceChangeRate': -0.066666666666667,
#    'date': '2010-12-08',
#    'source': 'ERA Kings Bay Realty',
#    'postingIsRental': False,
#    'time': 1291766400000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'ERA Kings Bay Realty',
#     'infoString3': None,
#     'infoString1': None},
#    'pricePerSquareFoot': 62,
#    'buyerAgent': None,
#    'event': 'Price change',
#    'price': 100800},
#   {'priceChangeRate': 0.030534351145038,
#    'date': '2010-12-04',
#    'source': 'ERA Kings Bay Realty',
#    'postingIsRental': False,
#    'time': 1291420800000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'ERA Kings Bay Realty',
#     'infoString3': None,
#     'infoString1': None},
#    'pricePerSquareFoot': 67,
#    'buyerAgent': None,
#    'event': 'Price change',
#    'price': 108000},
#   {'priceChangeRate': 0,
#    'date': '2010-11-11',
#    'source': 'ERA Kings Bay Realty',
#    'postingIsRental': False,
#    'time': 1289433600000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'ERA Kings Bay Realty',
#     'infoString3': None,
#     'infoString1': None},
#    'pricePerSquareFoot': 65,
#    'buyerAgent': None,
#    'event': 'Listed for sale',
#    'price': 104800}],
#  'favoriteCount': 0,
#  'schools': [{'link': 'https://www.greatschools.org/school?id=00276&state=GA',
#    'rating': 8,
#    'totalCount': 1,
#    'distance': 0.9,
#    'assigned': None,
#    'name': 'David L Rainer Elementary School',
#    'studentsPerTeacher': 16,
#    'isAssigned': True,
#    'size': 456,
#    'level': 'Primary',
#    'grades': 'PK-5',
#    'type': 'Public'},
#   {'link': 'https://www.greatschools.org/school?id=00278&state=GA',
#    'rating': 6,
#    'totalCount': 1,
#    'distance': 2.2,
#    'assigned': None,
#    'name': 'Camden Middle School',
#    'studentsPerTeacher': 16,
#    'isAssigned': True,
#    'size': 1046,
#    'level': 'Middle',
#    'grades': '6-8',
#    'type': 'Public'},
#   {'link': 'https://www.greatschools.org/school?id=00275&state=GA',
#    'rating': 9,
#    'totalCount': 1,
#    'distance': 3.6,
#    'assigned': None,
#    'name': 'Camden County High School',
#    'studentsPerTeacher': 16,
#    'isAssigned': True,
#    'size': 2504,
#    'level': 'High',
#    'grades': '9-12',
#    'type': 'Public'}],
#  'zestimateHighPercent': None,
#  'mlsid': '10036340',
#  'address': {'city': 'Kingsland',
#   'neighborhood': None,
#   'state': 'GA',
#   'streetAddress': '84 Whippoorwill Cir',
#   'zipcode': '31548'},
#  'city': 'Kingsland',
#  'providerListingID': None,
#  'country': 'USA',
#  'currency': 'USD',
#  'listed_by': {'agent_reason': 3,
#   'zpro': True,
#   'recent_sales': 0,
#   'review_count': 0,
#   'display_name': 'Stephana Dixon',
#   'badge_type': 'Listing Agent',
#   'business_name': 'BHHS Hodnett Cooper RealEstate',
#   'rating_average': 0,
#   'phone': {'prefix': '322', 'areacode': '912', 'number': '6715'},
#   'zuid': 'X1-ZU11jxzo064yn0p_5xifh',
#   'image_url': 'https://photos.zillowstatic.com/h_n/ISfwp1ca5si3kn0000000000.jpg'},
#  'contingentListingType': None}

# %%
# transform data to pandas dataframe
df_property_detail = pd.json_normalize(data=response.json())
print('Num of rows:', len(df_property_detail))
print('Num of cols:', len(df_property_detail.columns))
df_property_detail.head()
# Out:
# Num of rows: 1
# Num of cols: 257
#   listingProvider buildingPermits  propertyTaxRate  \
# 0            None            None             0.98
#
#                                   contact_recipients  longitude countyFIPS  \
# 0  [{'agent_reason': 1, 'zpro': None, 'recent_sal...  -81.66023      13039
#
#    cityId timeOnZillow                                                url  \
# 0   52779     146 days  /homedetails/84-Whippoorwill-Cir-Kingsland-GA-...
#
#    zestimate                                             imgSrc      zpid  \
# 0     235700  https://photos.zillowstatic.com/fp/9d94004ba25...  76375189
#
#   zipcode  livingAreaValue zestimateLowPercent  isListedByOwner  \
# 0   31548             1618                None            False
#
#   propertyTypeDimension        streetAddress county  \
# 0         Single Family  84 Whippoorwill Cir   None
#
#                                           taxHistory  stateId  countyId  \
# 0  [{'time': 1633211731420, 'valueIncreaseRate': ...       16       908
#
#            timeZone       homeType livingAreaUnits comingSoonOnMarketDate  \
# 0  America/New_York  SINGLE_FAMILY            sqft                   None
#
#    livingArea  bathrooms  annualHomeownersInsurance state  rentZestimate  \
# 0        1618          2                        924    GA           1649
#
#   building brokerId  yearBuilt                   brokerageName    dateSold  \
# 0     None     None       1986  BHHS Hodnett Cooper RealEstate  2022-05-09
#
#     price  pageViewCount                                        description  \
# 0  220000              0  Property being sold as is. Seller has never oc...
#
#       homeStatus homeFacts   latitude  datePosted  bedrooms  \
# 0  RECENTLY_SOLD      None  30.762964  2022-05-12         3
#
#                                          nearbyHomes monthlyHoaFee  \
# 0  [{'miniCardPhotos': [{'url': 'https://photos.z...          None
#
#                                         priceHistory  favoriteCount  \
# 0  [{'priceChangeRate': 0.1, 'date': '2022-05-09'...              0
#
#                                              schools zestimateHighPercent  \
# 0  [{'link': 'https://www.greatschools.org/school...                 None
#
#       mlsid       city providerListingID country currency  \
# 0  10036340  Kingsland              None     USA      USD
#
#   contingentListingType  solarPotential.sunScore  solarPotential.solarFactor  \
# 0                  None                    64.35                        3.04
#
#    solarPotential.buildFactor  solarPotential.climateFactor  \
# 0                          52                          6.67
#
#    solarPotential.electricityFactor  resoFacts.hasAttachedProperty  \
# 0                              2.64                          False
#
#   resoFacts.frontageType resoFacts.poolFeatures resoFacts.flooring  \
# 0                   None                   None     [Carpet, Tile]
#
#   resoFacts.foundationDetails resoFacts.accessibilityFeatures  \
# 0                      [Slab]                            None
#
#    resoFacts.hasGarage resoFacts.hasPetsAllowed resoFacts.bodyType  \
# 0                False                     None               None
#
#   resoFacts.topography resoFacts.landLeaseExpirationDate  \
# 0                 None                              None
#
#    resoFacts.hasAdditionalParcels resoFacts.waterViewYN  \
# 0                           False                  None
#
#                             resoFacts.atAGlanceFacts  \
# 0  [{'factLabel': 'Type', 'factValue': 'Single Fa...
#
#   resoFacts.offerReviewDate resoFacts.aboveGradeFinishedArea  \
# 0                      None                            1,618
#
#   resoFacts.buyerAgencyCompensationType resoFacts.carportSpaces  \
# 0                                  None                    None
#
#   resoFacts.cityRegion  resoFacts.mainLevelBathrooms resoFacts.hasPrivatePool  \
# 0            Kingsland                             2                     None
#
#   resoFacts.associationFeeIncludes resoFacts.waterSource  \
# 0                           [None]              [Public]
#
#   resoFacts.coveredSpaces resoFacts.inclusions  resoFacts.hasFireplace  \
# 0                    None                 None                   False
#
#   resoFacts.zoningDescription resoFacts.garageSpaces resoFacts.sewer  \
# 0                        None                   None  [Public Sewer]
#
#   resoFacts.elevationUnits resoFacts.exclusions  resoFacts.mainLevelBedrooms  \
# 0                     None                 None                            3
#
#   resoFacts.numberOfUnitsVacant resoFacts.hasWaterfrontView resoFacts.listAOR  \
# 0                          None                        None              None
#
#   resoFacts.lotSize resoFacts.entryLevel resoFacts.irrigationWaterRightsAcres  \
# 0              None                 None                                 None
#
#   resoFacts.greenWaterConservation resoFacts.stories resoFacts.livingArea  \
# 0                             None              None           1,618 sqft
#
#   resoFacts.numberOfUnitsInCommunity resoFacts.listingTerms  \
# 0                               None                   None
#
#   resoFacts.otherStructures resoFacts.associationFee resoFacts.marketingType  \
# 0                      None                     None                    None
#
#   resoFacts.greenIndoorAirQuality resoFacts.greenSustainability  \
# 0                            None                          None
#
#    resoFacts.hasHomeWarranty resoFacts.associationPhone  \
# 0                      False                       None
#
#   resoFacts.greenBuildingVerificationType resoFacts.elementarySchool  \
# 0                                    None             David L Rainer
#
#    resoFacts.bedrooms resoFacts.architecturalStyle resoFacts.listingId  \
# 0                   3                        Ranch                None
#
#   resoFacts.structureType resoFacts.interiorFeatures resoFacts.horseAmenities  \
# 0                   House        [Master Downstairs]                     None
#
#   resoFacts.electric resoFacts.developmentStatus resoFacts.lotFeatures  \
# 0               None                        None               [Level]
#
#   resoFacts.roofType resoFacts.waterSources resoFacts.constructionMaterials  \
# 0        Composition                   None                         [Tabby]
#
#   resoFacts.fireplaceFeatures resoFacts.doorFeatures     resoFacts.appliances  \
# 0                        None                   None  [Electric Water Heater]
#
#    resoFacts.daysOnZillow resoFacts.bathroomsPartial  resoFacts.bathroomsHalf  \
# 0                     146                       None                        0
#
#   resoFacts.depositsAndFees  resoFacts.canRaiseHorses resoFacts.buildingName  \
# 0                      None                     False                   None
#
#    resoFacts.hasAssociation resoFacts.petsMaxWeight resoFacts.commonWalls  \
# 0                     False                    None                  None
#
#   resoFacts.totalActualRent resoFacts.additionalParcelsDescription  \
# 0                      None                                   None
#
#   resoFacts.associationName resoFacts.allowedPets resoFacts.communityFeatures  \
# 0                      None                  None                      [None]
#
#   resoFacts.tenantPays resoFacts.middleOrJuniorSchool  \
# 0                 None                         Camden
#
#   resoFacts.lotSizeDimensions resoFacts.roadSurfaceType  \
# 0                        None                      None
#
#    resoFacts.hasOpenParking  resoFacts.yearBuilt  \
# 0                      True                 1986
#
#   resoFacts.livingAreaRangeUnits resoFacts.irrigationWaterRightsYN  \
# 0                           None                              None
#
#    resoFacts.bathroomsFull resoFacts.horseYN resoFacts.incomeIncludes  \
# 0                        2              None                     None
#
#   resoFacts.highSchool resoFacts.leaseTerm resoFacts.elevation  \
# 0        Camden County                None                None
#
#   resoFacts.cropsIncludedYN resoFacts.attic resoFacts.subdivisionName  \
# 0                      None            None                  Deer Run
#
#   resoFacts.windowFeatures resoFacts.ownership resoFacts.woodedArea  \
# 0                     None                None                 None
#
#   resoFacts.middleOrJuniorSchoolDistrict resoFacts.associationPhone2  \
# 0                                   None                        None
#
#   resoFacts.buyerAgencyCompensation resoFacts.heating  \
# 0                              None       [Heat Pump]
#
#   resoFacts.frontageLength resoFacts.virtualTourURLUnbranded  \
# 0                     None                              None
#
#   resoFacts.associationAmenities  resoFacts.propertySubType  \
# 0                           None  [Single Family Residence]
#
#    resoFacts.hasCooling resoFacts.belowGradeFinishedArea  \
# 0                  True                                0
#
#    resoFacts.hasElectricOnProperty resoFacts.foundationArea resoFacts.zoning  \
# 0                             True                     None             None
#
#   resoFacts.hoaFee resoFacts.livingAreaRange  resoFacts.basementYN  \
# 0             None                      None                 False
#
#   resoFacts.availabilityDate resoFacts.waterBodyName  \
# 0                       None                    None
#
#   resoFacts.waterfrontFeatures resoFacts.specialListingConditions  \
# 0                         None                               None
#
#   resoFacts.buildingAreaSource  resoFacts.taxAnnualAmount  resoFacts.parking  \
# 0                         None                       1714                  0
#
#    resoFacts.hasView resoFacts.virtualTour resoFacts.securityFeatures  \
# 0              False                  None                       None
#
#   resoFacts.cooling resoFacts.entryLocation resoFacts.levels  \
# 0     [Central Air]                    None              One
#
#   resoFacts.ownershipType resoFacts.basement  resoFacts.onMarketDate  \
# 0                    None               None           1649376000000
#
#   resoFacts.waterView resoFacts.laundryFeatures  resoFacts.hasAttachedGarage  \
# 0                None        [In Garage, Other]                        False
#
#   resoFacts.fencing resoFacts.spaFeatures  resoFacts.bathrooms  \
# 0              None                  None                    2
#
#   resoFacts.homeType resoFacts.isSeniorCommunity resoFacts.municipality  \
# 0       SingleFamily                        None                   None
#
#   resoFacts.bathroomsThreeQuarter  resoFacts.hasSpa resoFacts.otherParking  \
# 0                            None             False                   None
#
#   resoFacts.associationFee2 resoFacts.parcelNumber  resoFacts.hasHeating  \
# 0                      None               108C 003                  True
#
#   resoFacts.associationName2 resoFacts.hasRentControl  \
# 0                       None                     None
#
#   resoFacts.elementarySchoolDistrict resoFacts.otherEquipment  \
# 0                               None                     None
#
#   resoFacts.parkingFeatures resoFacts.buildingArea  resoFacts.furnished  \
# 0             [Parking Pad]                  1,618                False
#
#   resoFacts.vegetation resoFacts.patioAndPorchFeatures  \
# 0                 None                            None
#
#   resoFacts.buildingFeatures resoFacts.builderName  \
# 0                       None                  None
#
#   resoFacts.highSchoolDistrict resoFacts.propertyCondition  \
# 0                         None                      Resale
#
#   resoFacts.storiesTotal resoFacts.yearBuiltEffective  resoFacts.fireplaces  \
# 0                   None                         None                     0
#
#   resoFacts.bathroomsOneQuarter resoFacts.builderModel resoFacts.gas  \
# 0                          None                   None          None
#
#                                  resoFacts.utilities  \
# 0  [Electricity Available, Phone Available, Sewer...
#
#   resoFacts.greenEnergyEfficient resoFacts.landLeaseAmount  \
# 0                           None                      None
#
#    resoFacts.isNewConstruction  resoFacts.hasLandLease  \
# 0                        False                   False
#
#    resoFacts.pricePerSquareFoot  resoFacts.hasCarport  \
# 0                           136                 False
#
#   resoFacts.openParkingSpaces mortgageRates.arm5Rate  \
# 0                        None                   None
#
#    mortgageRates.fifteenYearFixedRate  mortgageRates.thirtyYearFixedRate  \
# 0                               6.008                              6.625
#
#   address.city address.neighborhood address.state address.streetAddress  \
# 0    Kingsland                 None            GA   84 Whippoorwill Cir
#
#   address.zipcode  listed_by.agent_reason  listed_by.zpro  \
# 0           31548                       3            True
#
#    listed_by.recent_sales  listed_by.review_count listed_by.display_name  \
# 0                       0                       0         Stephana Dixon
#
#   listed_by.badge_type         listed_by.business_name  \
# 0        Listing Agent  BHHS Hodnett Cooper RealEstate
#
#    listed_by.rating_average listed_by.phone.prefix listed_by.phone.areacode  \
# 0                         0                    322                      912
#
#   listed_by.phone.number            listed_by.zuid  \
# 0                   6715  X1-ZU11jxzo064yn0p_5xifh
#
#                                  listed_by.image_url
# 0  https://photos.zillowstatic.com/h_n/ISfwp1ca5s...

# %%
# retrieve property detail elements
bedrooms = df_property_detail['bedrooms'].iloc[0]
bathrooms = df_property_detail['bathrooms'].iloc[0]
year_built = df_property_detail['yearBuilt'].iloc[0]
property_type = df_property_detail['homeType'].iloc[0]
living_area = df_property_detail['resoFacts.livingArea'].iloc[0]
lot_size = df_property_detail['resoFacts.lotSize'].iloc[0]
lot_dimensions = df_property_detail['resoFacts.lotSizeDimensions'].iloc[0]
zoning = df_property_detail['resoFacts.zoning'].iloc[0]
livingAreaValue = df_property_detail['livingAreaValue'].iloc[0]
schools = df_property_detail['schools'].iloc[0]
# estimates
zestimate = df_property_detail['zestimate'].iloc[0]
rent_zestimate = df_property_detail['rentZestimate'].iloc[0]

print('PROPERTY DETAILS FOR: ', property_address)
print('------------------------------------------------------------------')
print('  Bedrooms: {}'.format( bedrooms))
print('  Bathrooms: {}'.format( bathrooms))
print('  Year Built: {}'.format( year_built))
print('  Living Area: {}'.format( living_area))
print('  Lot Size: {}'.format( lot_size))
print('  Lot Dimensions: {}'.format( lot_dimensions))
print('  Zoning: {}'.format( zoning))
print('  livingAreaValue: {}'.format( livingAreaValue))
print('  schools: {}'.format( schools))
print('  Property Type: {}'.format( property_type))
print('  Zestimate:  {}'.format(zestimate))
print('  Rent Zestimate: {}'.format(rent_zestimate))
# Out:
# PROPERTY DETAILS FOR:  84 Whippoorwill Circle, Kingsland, GA 31548
# ------------------------------------------------------------------
#   Bedrooms: 3
#   Bathrooms: 2
#   Year Built: 1986
#   Living Area: 1,618 sqft
#   Lot Size: None
#   Lot Dimensions: None
#   Zoning: None
#   livingAreaValue: 1618
#   schools: [{'link': 'https://www.greatschools.org/school?id=00276&state=GA', 'rating': 8, 'totalCount': 1, 'distance': 0.9, 'assigned': None, 'name': 'David L Rainer Elementary School', 'studentsPerTeacher': 16, 'isAssigned': True, 'size': 456, 'level': 'Primary', 'grades': 'PK-5', 'type': 'Public'}, {'link': 'https://www.greatschools.org/school?id=00278&state=GA', 'rating': 6, 'totalCount': 1, 'distance': 2.2, 'assigned': None, 'name': 'Camden Middle School', 'studentsPerTeacher': 16, 'isAssigned': True, 'size': 1046, 'level': 'Middle', 'grades': '6-8', 'type': 'Public'}, {'link': 'https://www.greatschools.org/school?id=00275&state=GA', 'rating': 9, 'totalCount': 1, 'distance': 3.6, 'assigned': None, 'name': 'Camden County High School', 'studentsPerTeacher': 16, 'isAssigned': True, 'size': 2504, 'level': 'High', 'grades': '9-12', 'type': 'Public'}]
#   Property Type: SINGLE_FAMILY
#   Zestimate:  235700
#   Rent Zestimate: 1649

# %% [markdown]
# ### <font color=blue> The Short Look Up csv file created from data provided by Haystack, but consists of only 4 columns

# %%
# read file
df_upload = pd.read_csv('short_lookup.csv')
print('Num of rows:', len(df_upload))
df_upload.head()
# Out:
# Num of rows: 5146
#                         address         city    state    zip
# 0            101 College Street    Kingsland  Georgia  31548
# 1  169 School House Creek Drive  Saint Marys  Georgia  31558
# 2          1621 Sandpiper Court  Saint Marys  Georgia  31558
# 3  346 Laurel Landing Boulevard    Kingsland  Georgia  31548
# 4                81 Ossabaw Way      Waverly  Georgia  31565

# %% [markdown]
# ### <font color=blue> This is a one time data pull script, do not run again!

# %%
# create empty list to store api response for property details
df_list = []
zpid_list = []

# iterate through dataframe
for index, row in df_upload.iterrows():
  # get property address attributes by column name
  street = row['address']
  city = row['city']
  state = row['state']
  zip_code = row['zip'] 

  # get zpid
  zpid = get_zpid(street=street, city=city, state=state, zip_code=zip_code)
  zpid_list.append(zpid)

  # wait 1 second to not overload Google Search
  time.sleep(1.5)

  # get property details
  # catch errors (possibly no zpid)
  try:
    response = get_property_detail(rapid_api_key, zpid)
    _df = pd.json_normalize(data=response.json())
    # append data to list of property details
    df_list.append(_df)
  except:
    print('Unable to retrieve data for : {0}, {1}, {2}, {3}'.format(street, city, state, zip_code))
# Out:
# Unable to retrieve data for : 4342 White Surrey Drive NW, Kennesaw, Georgia, 30144

# %%
# join property details data
df_prop_detail = pd.concat(df_list)
df_prop_detail.head()

# %%
len(df_prop_detail.zpid.unique())
# Out:
# 4609

# %% [markdown]
# ### <font color=blue> We are saving the zillow data with 200+ attributes, which will save us from re-running the Rapid API code

# %%
#Save data to a file for manual inspection
df_prop_detail.to_csv('full_output.csv', index=False)

# %%
import json
with open("zpid_list", "w") as fp:
     json.dump(zpid_list, fp)
